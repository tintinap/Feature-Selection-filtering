# %%
#library
import pandas as pd
import numpy as np
import itertools
import seaborn as sns
import math

# %% [markdown]
# <H1>Dataset : Pima Indians Diabetes

# %%
df = pd.read_csv("../dataset/diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# <h1>Features

# %%
features = df.columns.tolist()[:-1]
features
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age']

# %%
X = df[features]
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %%
label = 'Outcome'
label
# Out:
# 'Outcome'

# %%
y = df[label]
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
num_feats = X.shape[1]
num_feats
# Out:
# 8

# %% [markdown]
# <h1>Manhattan Distance between each feature and label

# %% [markdown]
# <h2> Normalization Data

# %%
X = df[features].apply(lambda x: (x - x.min()) / (x.max() - x.min()))
X
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.352941  0.743719       0.590164       0.353535  0.000000  0.500745
# 1       0.058824  0.427136       0.540984       0.292929  0.000000  0.396423
# 2       0.470588  0.919598       0.524590       0.000000  0.000000  0.347243
# 3       0.058824  0.447236       0.540984       0.232323  0.111111  0.418778
# 4       0.000000  0.688442       0.327869       0.353535  0.198582  0.642325
# ..           ...       ...            ...            ...       ...       ...
# 763     0.588235  0.507538       0.622951       0.484848  0.212766  0.490313
# 764     0.117647  0.613065       0.573770       0.272727  0.000000  0.548435
# 765     0.294118  0.608040       0.590164       0.232323  0.132388  0.390462
# 766     0.058824  0.633166       0.491803       0.000000  0.000000  0.448584
# 767     0.058824  0.467337       0.573770       0.313131  0.000000  0.453055
#
#      DiabetesPedigreeFunction       Age
# 0                    0.234415  0.483333
# 1                    0.116567  0.166667
# 2                    0.253629  0.183333
# 3                    0.038002  0.000000
# 4                    0.943638  0.200000
# ..                        ...       ...
# 763                  0.039710  0.700000
# 764                  0.111870  0.100000
# 765                  0.071307  0.150000
# 766                  0.115713  0.433333
# 767                  0.101196  0.033333
#
# [768 rows x 8 columns]

# %% [markdown]
# <h2> Manhattan Distance Table

# %%
df_md = {'Outcome': []}

for f in features:
    df_md['Outcome'].append(np.mean([math.sqrt(abs(a[0]-a[1])) for a in zip(X[f], y)]))

df_md = pd.DataFrame.from_dict(df_md)
df_md.index = features
df_md
# Out:
#                            Outcome
# Pregnancies               0.537556
# Glucose                   0.658338
# BloodPressure             0.697390
# SkinThickness             0.547161
# Insulin                   0.452641
# BMI                       0.670003
# DiabetesPedigreeFunction  0.541908
# Age                       0.518116

# %% [markdown]
# <h1> Function

# %%
def grouping_attribute_score(attrubutes, value):
    '''combine value to dictionary format'''
    return {"attributes": attrubutes, "value": value}
#can modify to be object in the future

# %%
def find_best_subset(subset_score, max_min='max'):
    """find best score of subset subset score is list of grouping_attribute_score
        max_min (str) : can be only 'max' or 'min' to define the best value
    """
    #still available for only a group of attributes
    print('========================================== find best value ===================================')
    best_subset_score = []
    
    if max_min == 'min':
        # min is the best
        subset_score.sort(key=lambda x: x['value'], reverse=False)
    else:        
        #max is the best
        subset_score.sort(key=lambda x: x['value'], reverse=True)

    best_subset_score.append(subset_score[0])
    print(best_subset_score)
    print("=============================================================================================")
    return best_subset_score
# return [{'attrubute': ('Glucose', 'BMI'), 'value': 0.3796380304756596}]

# %%
def cal_best(algo_round, max_min='max'):
    """match all subset and find the best one
        max_min (str) : can be only 'max' or 'min' to define the best value
    """
    #start calculating
    subset_score = []
    subset_mean = []
    
    #use mean of all correlation of subset
    for atrs in algo_round:
        temp_score_mean = []
        for i in atrs:
            #manhattan distance
            md = df_md[label][i]
            temp_score_mean.append(md)
        subset_mean.append(np.mean(temp_score_mean)) #score
        
    for atrs,mean_score in zip(algo_round,subset_mean):
        subset_score.append(grouping_attribute_score(atrs, mean_score))
    [print(i) for i in subset_score]
    return find_best_subset(subset_score=subset_score, max_min=max_min)

# %% [markdown]
# <h1>SFFS

# %%
best_subset_per_round = []
combination_history = []
for num in range(1, num_feats+1):   
    print("========================================== Subset_Score Round", num,'=============================')
    if num == 1: #1st round
        #combination of subset in each round
        sfs_round = list(itertools.combinations(features, num))

        print()        
        best_subset_per_round.append(cal_best(algo_round=sfs_round, max_min='max'))
        print()
        
    elif num == 2 or num == 3:
        sfs_round = list(itertools.combinations(features, num))
        
        #hv to pop non-best_subset out
        sfs_round_temp = []
        for i in range(len(sfs_round)):
            if all(attr in sfs_round[i] for attr in best_subset_per_round[num-2][0]['attributes']):
                sfs_round_temp.append(sfs_round[i])
        sfs_round = sfs_round_temp
#         print('sfs_round2:=================', sfs_round)
        #record the history of combination
        combination_history.extend(sfs_round)
        print('combination_hist:=====================>', combination_history)
        
        print()
        best_subset_per_round.append(cal_best(algo_round=sfs_round, max_min='max'))
        print()
        
    else: #other round
        #combination of subset in each round
        print()
        #last best_subset
#         print(best_subset_per_round[-1][0])
#         print(best_subset_per_round[num-2])
        #2 previous check index number
#         print(num-2)
        #combination
        sfs_check = list(itertools.combinations(best_subset_per_round[-1][0]['attributes'], num-2))
        print('combination of previous round:===========>', sfs_check)
        #check history
        [sfs_check.remove(i) for i in sfs_check if i in combination_history]
                
        print('never occured combination:===============>', sfs_check)
        #combination in the same number as last round that has sfs_check inside
        check_temp = []
        comb_temp = list(itertools.combinations(features, num-1))
        for j in range(len(sfs_check)):
            for i in range(len(comb_temp)):
                if all(attr in comb_temp[i] for attr in sfs_check[j]):
                    check_temp.append(comb_temp[i])
        comb_temp = check_temp
        #check history
        [comb_temp.remove(i) for i in comb_temp if i in combination_history]
#         print(comb_temp)
        print()
        print('------------------------------------------calculate sbs check------------------------------------------')
        sbs_check = cal_best(comb_temp)
        print('sbs check:',sbs_check)
        print('current best', best_subset_per_round[-1])
        if sbs_check[0]['value'] > best_subset_per_round[-1][0]['value']: #max is the best
            print('privoue best_subset_score ----->', best_subset_per_round)
            print('new value')
            best_subset_per_round[-1][0] = sbs_check[0]
        print('current best_subset_score ----->', best_subset_per_round)
        print('------------------------------------------calculate sbs check------------------------------------------')
        print()
        sfs_round = list(itertools.combinations(features, num))
        
        #hv to pop non-best_subset out
        sfs_round_temp = []
#         print('num-3:', num-3, 'num:',num)# index of before data
        for i in range(len(sfs_round)):
            if all(attr in sfs_round[i] for attr in best_subset_per_round[num-2][0]['attributes']):
                sfs_round_temp.append(sfs_round[i])
        sfs_round = sfs_round_temp
#         print('sfs_round_other:=================', sfs_round)
        #record the history of combination
        combination_history.extend(sfs_round)
        print('combination_hist:=====================>', combination_history)
        
        print()
        best_subset_per_round.append(cal_best(algo_round=sfs_round, max_min='max'))
        print()       
        
print()
print('best_subset_per_round :',"\n", '=============== SubsetRanking ===============')
# [print(i) for i in best_subset_per_round]

best_temp = [i[0] for i in best_subset_per_round]
best_subset_per_round = best_temp
best_subset_per_round.sort(key=lambda x: x['value'], reverse=True) # max is the best
best_subset_per_round
# Out:
# ========================================== Subset_Score Round 1 =============================
#
# {'attributes': ('Pregnancies',), 'value': 0.5375557074352147}
# {'attributes': ('Glucose',), 'value': 0.6583376683966278}
# {'attributes': ('BloodPressure',), 'value': 0.6973898871046167}
# {'attributes': ('SkinThickness',), 'value': 0.5471606317348762}
# {'attributes': ('Insulin',), 'value': 0.45264096175692536}
# {'attributes': ('BMI',), 'value': 0.6700027417225339}
# {'attributes': ('DiabetesPedigreeFunction',), 'value': 0.5419076500775697}
# {'attributes': ('Age',), 'value': 0.5181159325052546}
# ========================================== find best value ===================================
# [{'attributes': ('BloodPressure',), 'value': 0.6973898871046167}]
# =============================================================================================
#
# ========================================== Subset_Score Round 2 =============================
# combination_hist:=====================> [('Pregnancies', 'BloodPressure'), ('Glucose', 'BloodPressure'), ('BloodPressure', 'SkinThickness'), ('BloodPressure', 'Insulin'), ('BloodPressure', 'BMI'), ('BloodPressure', 'DiabetesPedigreeFunction'), ('BloodPressure', 'Age')]
#
# {'attributes': ('Pregnancies', 'BloodPressure'), 'value': 0.6174727972699157}
# {'attributes': ('Glucose', 'BloodPressure'), 'value': 0.6778637777506222}
# {'attributes': ('BloodPressure', 'SkinThickness'), 'value': 0.6222752594197465}
# {'attributes': ('BloodPressure', 'Insulin'), 'value': 0.575015424430771}
# {'attributes': ('BloodPressure', 'BMI'), 'value': 0.6836963144135753}
# {'attributes': ('BloodPressure', 'DiabetesPedigreeFunction'), 'value': 0.6196487685910932}
# {'attributes': ('BloodPressure', 'Age'), 'value': 0.6077529098049357}
# ========================================== find best value ===================================
# [{'attributes': ('BloodPressure', 'BMI'), 'value': 0.6836963144135753}]
# =============================================================================================
#
# ========================================== Subset_Score Round 3 =============================
# combination_hist:=====================> [('Pregnancies', 'BloodPressure'), ('Glucose', 'BloodPressure'), ('BloodPressure', 'SkinThickness'), ('BloodPressure', 'Insulin'), ('BloodPressure', 'BMI'), ('BloodPressure', 'DiabetesPedigreeFunction'), ('BloodPressure', 'Age'), ('Pregnancies', 'BloodPressure', 'BMI'), ('Glucose', 'BloodPressure', 'BMI'), ('BloodPressure', 'SkinThickness', 'BMI'), ('BloodPressure', 'Insulin', 'BMI'), ('BloodPressure', 'BMI', 'DiabetesPedigreeFunction'), ('BloodPressure', 'BMI', 'Age')]
#
# {'attributes': ('Pregnancies', 'BloodPressure', 'BMI'), 'value': 0.6349827787541217}
# {'attributes': ('Glucose', 'BloodPressure', 'BMI'), 'value': 0.6752434324079261}
# {'attributes': ('BloodPressure', 'SkinThickness', 'BMI'), 'value': 0.6381844201873422}
# {'attributes': ('BloodPressure', 'Insulin', 'BMI'), 'value': 0.6066778635280253}
# {'attributes': ('BloodPressure', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.6364334263015734}
# {'attributes': ('BloodPressure', 'BMI', 'Age'), 'value': 0.6285028537774684}
# ========================================== find best value ===================================
# [{'attributes': ('Glucose', 'BloodPressure', 'BMI'), 'value': 0.6752434324079261}]
# =============================================================================================
#
# ========================================== Subset_Score Round 4 =============================
#
# combination of previous round:===========> [('Glucose', 'BloodPressure'), ('Glucose', 'BMI'), ('BloodPressure', 'BMI')]
# never occured combination:===============> [('Glucose', 'BMI')]
#
# ------------------------------------------calculate sbs check------------------------------------------
# {'attributes': ('Pregnancies', 'Glucose', 'BMI'), 'value': 0.6219653725181254}
# {'attributes': ('Glucose', 'SkinThickness', 'BMI'), 'value': 0.625167013951346}
# {'attributes': ('Glucose', 'Insulin', 'BMI'), 'value': 0.593660457292029}
# {'attributes': ('Glucose', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.6234160200655771}
# {'attributes': ('Glucose', 'BMI', 'Age'), 'value': 0.615485447541472}
# ========================================== find best value ===================================
# [{'attributes': ('Glucose', 'SkinThickness', 'BMI'), 'value': 0.625167013951346}]
# =============================================================================================
# sbs check: [{'attributes': ('Glucose', 'SkinThickness', 'BMI'), 'value': 0.625167013951346}]
# current best [{'attributes': ('Glucose', 'BloodPressure', 'BMI'), 'value': 0.6752434324079261}]
# current best_subset_score -----> [[{'attributes': ('BloodPressure',), 'value': 0.6973898871046167}], [{'attributes': ('BloodPressure', 'BMI'), 'value': 0.6836963144135753}], [{'attributes': ('Glucose', 'BloodPressure', 'BMI'), 'value': 0.6752434324079261}]]
# ------------------------------------------calculate sbs check------------------------------------------
#
# combination_hist:=====================> [('Pregnancies', 'BloodPressure'), ('Glucose', 'BloodPressure'), ('BloodPressure', 'SkinThickness'), ('BloodPressure', 'Insulin'), ('BloodPressure', 'BMI'), ('BloodPressure', 'DiabetesPedigreeFunction'), ('BloodPressure', 'Age'), ('Pregnancies', 'BloodPressure', 'BMI'), ('Glucose', 'BloodPressure', 'BMI'), ('BloodPressure', 'SkinThickness', 'BMI'), ('BloodPressure', 'Insulin', 'BMI'), ('BloodPressure', 'BMI', 'DiabetesPedigreeFunction'), ('BloodPressure', 'BMI', 'Age'), ('Pregnancies', 'Glucose', 'BloodPressure', 'BMI'), ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI'), ('Glucose', 'BloodPressure', 'Insulin', 'BMI'), ('Glucose', 'BloodPressure', 'BMI', 'DiabetesPedigreeFunction'), ('Glucose', 'BloodPressure', 'BMI', 'Age')]
#
# {'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'BMI'), 'value': 0.6408215011647482}
# {'attributes': ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI'), 'value': 0.6432227322396636}
# {'attributes': ('Glucose', 'BloodPressure', 'Insulin', 'BMI'), 'value': 0.6195928147451759}
# {'attributes': ('Glucose', 'BloodPressure', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.641909486825337}
# {'attributes': ('Glucose', 'BloodPressure', 'BMI', 'Age'), 'value': 0.6359615574322582}
# ========================================== find best value ===================================
# [{'attributes': ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI'), 'value': 0.6432227322396636}]
# =============================================================================================
#
# ========================================== Subset_Score Round 5 =============================
#
# combination of previous round:===========> [('Glucose', 'BloodPressure', 'SkinThickness'), ('Glucose', 'BloodPressure', 'BMI'), ('Glucose', 'SkinThickness', 'BMI'), ('BloodPressure', 'SkinThickness', 'BMI')]
# never occured combination:===============> [('Glucose', 'BloodPressure', 'SkinThickness'), ('Glucose', 'SkinThickness', 'BMI')]
#
# ------------------------------------------calculate sbs check------------------------------------------
# {'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness'), 'value': 0.6101109736678338}
# {'attributes': ('Glucose', 'BloodPressure', 'SkinThickness', 'Insulin'), 'value': 0.5888822872482615}
# {'attributes': ('Glucose', 'BloodPressure', 'SkinThickness', 'DiabetesPedigreeFunction'), 'value': 0.6111989593284226}
# {'attributes': ('Glucose', 'BloodPressure', 'SkinThickness', 'Age'), 'value': 0.6052510299353439}
# {'attributes': ('Pregnancies', 'Glucose', 'SkinThickness', 'BMI'), 'value': 0.6032641873223131}
# {'attributes': ('Glucose', 'SkinThickness', 'Insulin', 'BMI'), 'value': 0.5820355009027408}
# {'attributes': ('Glucose', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.6043521729829019}
# {'attributes': ('Glucose', 'SkinThickness', 'BMI', 'Age'), 'value': 0.5984042435898231}
# ========================================== find best value ===================================
# [{'attributes': ('Glucose', 'BloodPressure', 'SkinThickness', 'DiabetesPedigreeFunction'), 'value': 0.6111989593284226}]
# =============================================================================================
# sbs check: [{'attributes': ('Glucose', 'BloodPressure', 'SkinThickness', 'DiabetesPedigreeFunction'), 'value': 0.6111989593284226}]
# current best [{'attributes': ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI'), 'value': 0.6432227322396636}]
# current best_subset_score -----> [[{'attributes': ('BloodPressure',), 'value': 0.6973898871046167}], [{'attributes': ('BloodPressure', 'BMI'), 'value': 0.6836963144135753}], [{'attributes': ('Glucose', 'BloodPressure', 'BMI'), 'value': 0.6752434324079261}], [{'attributes': ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI'), 'value': 0.6432227322396636}]]
# ------------------------------------------calculate sbs check------------------------------------------
#
# combination_hist:=====================> [('Pregnancies', 'BloodPressure'), ('Glucose', 'BloodPressure'), ('BloodPressure', 'SkinThickness'), ('BloodPressure', 'Insulin'), ('BloodPressure', 'BMI'), ('BloodPressure', 'DiabetesPedigreeFunction'), ('BloodPressure', 'Age'), ('Pregnancies', 'BloodPressure', 'BMI'), ('Glucose', 'BloodPressure', 'BMI'), ('BloodPressure', 'SkinThickness', 'BMI'), ('BloodPressure', 'Insulin', 'BMI'), ('BloodPressure', 'BMI', 'DiabetesPedigreeFunction'), ('BloodPressure', 'BMI', 'Age'), ('Pregnancies', 'Glucose', 'BloodPressure', 'BMI'), ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI'), ('Glucose', 'BloodPressure', 'Insulin', 'BMI'), ('Glucose', 'BloodPressure', 'BMI', 'DiabetesPedigreeFunction'), ('Glucose', 'BloodPressure', 'BMI', 'Age'), ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI'), ('Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI'), ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'Age')]
#
# {'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI'), 'value': 0.6220893272787739}
# {'attributes': ('Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI'), 'value': 0.605106378143116}
# {'attributes': ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.6229597158072449}
# {'attributes': ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'Age'), 'value': 0.6182013722927818}
# ========================================== find best value ===================================
# [{'attributes': ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.6229597158072449}]
# =============================================================================================
#
# ========================================== Subset_Score Round 6 =============================
#
# combination of previous round:===========> [('Glucose', 'BloodPressure', 'SkinThickness', 'BMI'), ('Glucose', 'BloodPressure', 'SkinThickness', 'DiabetesPedigreeFunction'), ('Glucose', 'BloodPressure', 'BMI', 'DiabetesPedigreeFunction'), ('Glucose', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), ('BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction')]
# never occured combination:===============> [('Glucose', 'BloodPressure', 'SkinThickness', 'DiabetesPedigreeFunction'), ('Glucose', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), ('BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction')]
#
# ------------------------------------------calculate sbs check------------------------------------------
# {'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'DiabetesPedigreeFunction'), 'value': 0.596470308949781}
# {'attributes': ('Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'DiabetesPedigreeFunction'), 'value': 0.5794873598141231}
# {'attributes': ('Glucose', 'BloodPressure', 'SkinThickness', 'DiabetesPedigreeFunction', 'Age'), 'value': 0.592582353963789}
# {'attributes': ('Pregnancies', 'Glucose', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.5909928798733645}
# {'attributes': ('Glucose', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.5740099307377066}
# {'attributes': ('Glucose', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction', 'Age'), 'value': 0.5871049248873724}
# {'attributes': ('Pregnancies', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.5988033236149622}
# {'attributes': ('BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.5818203744793043}
# {'attributes': ('BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction', 'Age'), 'value': 0.5949153686289702}
# ========================================== find best value ===================================
# [{'attributes': ('Pregnancies', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.5988033236149622}]
# =============================================================================================
# sbs check: [{'attributes': ('Pregnancies', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.5988033236149622}]
# current best [{'attributes': ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.6229597158072449}]
# current best_subset_score -----> [[{'attributes': ('BloodPressure',), 'value': 0.6973898871046167}], [{'attributes': ('BloodPressure', 'BMI'), 'value': 0.6836963144135753}], [{'attributes': ('Glucose', 'BloodPressure', 'BMI'), 'value': 0.6752434324079261}], [{'attributes': ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI'), 'value': 0.6432227322396636}], [{'attributes': ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.6229597158072449}]]
# ------------------------------------------calculate sbs check------------------------------------------
#
# combination_hist:=====================> [('Pregnancies', 'BloodPressure'), ('Glucose', 'BloodPressure'), ('BloodPressure', 'SkinThickness'), ('BloodPressure', 'Insulin'), ('BloodPressure', 'BMI'), ('BloodPressure', 'DiabetesPedigreeFunction'), ('BloodPressure', 'Age'), ('Pregnancies', 'BloodPressure', 'BMI'), ('Glucose', 'BloodPressure', 'BMI'), ('BloodPressure', 'SkinThickness', 'BMI'), ('BloodPressure', 'Insulin', 'BMI'), ('BloodPressure', 'BMI', 'DiabetesPedigreeFunction'), ('BloodPressure', 'BMI', 'Age'), ('Pregnancies', 'Glucose', 'BloodPressure', 'BMI'), ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI'), ('Glucose', 'BloodPressure', 'Insulin', 'BMI'), ('Glucose', 'BloodPressure', 'BMI', 'DiabetesPedigreeFunction'), ('Glucose', 'BloodPressure', 'BMI', 'Age'), ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI'), ('Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI'), ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'Age'), ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), ('Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction'), ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction', 'Age')]
#
# {'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.6087257144119065}
# {'attributes': ('Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.5945732567988583}
# {'attributes': ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction', 'Age'), 'value': 0.6054857519235798}
# ========================================== find best value ===================================
# [{'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.6087257144119065}]
# =============================================================================================
#
# ========================================== Subset_Score Round 7 =============================
#
# combination of previous round:===========> [('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI'), ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'DiabetesPedigreeFunction'), ('Pregnancies', 'Glucose', 'BloodPressure', 'BMI', 'DiabetesPedigreeFunction'), ('Pregnancies', 'Glucose', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), ('Pregnancies', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction')]
# never occured combination:===============> [('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'DiabetesPedigreeFunction'), ('Pregnancies', 'Glucose', 'BloodPressure', 'BMI', 'DiabetesPedigreeFunction'), ('Pregnancies', 'Glucose', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), ('Pregnancies', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction')]
#
# ------------------------------------------calculate sbs check------------------------------------------
# {'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'DiabetesPedigreeFunction'), 'value': 0.572498751084305}
# {'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'DiabetesPedigreeFunction', 'Age'), 'value': 0.5834112462090266}
# {'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'Insulin', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.592972436082248}
# {'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'BMI', 'DiabetesPedigreeFunction', 'Age'), 'value': 0.6038849312069695}
# {'attributes': ('Pregnancies', 'Glucose', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.5679342268539579}
# {'attributes': ('Pregnancies', 'Glucose', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction', 'Age'), 'value': 0.5788467219786795}
# {'attributes': ('Pregnancies', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.5744429299719561}
# {'attributes': ('Pregnancies', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction', 'Age'), 'value': 0.5853554250966776}
# ========================================== find best value ===================================
# [{'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'BMI', 'DiabetesPedigreeFunction', 'Age'), 'value': 0.6038849312069695}]
# =============================================================================================
# sbs check: [{'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'BMI', 'DiabetesPedigreeFunction', 'Age'), 'value': 0.6038849312069695}]
# current best [{'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.6087257144119065}]
# current best_subset_score -----> [[{'attributes': ('BloodPressure',), 'value': 0.6973898871046167}], [{'attributes': ('BloodPressure', 'BMI'), 'value': 0.6836963144135753}], [{'attributes': ('Glucose', 'BloodPressure', 'BMI'), 'value': 0.6752434324079261}], [{'attributes': ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI'), 'value': 0.6432227322396636}], [{'attributes': ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.6229597158072449}], [{'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.6087257144119065}]]
# ------------------------------------------calculate sbs check------------------------------------------
#
# combination_hist:=====================> [('Pregnancies', 'BloodPressure'), ('Glucose', 'BloodPressure'), ('BloodPressure', 'SkinThickness'), ('BloodPressure', 'Insulin'), ('BloodPressure', 'BMI'), ('BloodPressure', 'DiabetesPedigreeFunction'), ('BloodPressure', 'Age'), ('Pregnancies', 'BloodPressure', 'BMI'), ('Glucose', 'BloodPressure', 'BMI'), ('BloodPressure', 'SkinThickness', 'BMI'), ('BloodPressure', 'Insulin', 'BMI'), ('BloodPressure', 'BMI', 'DiabetesPedigreeFunction'), ('BloodPressure', 'BMI', 'Age'), ('Pregnancies', 'Glucose', 'BloodPressure', 'BMI'), ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI'), ('Glucose', 'BloodPressure', 'Insulin', 'BMI'), ('Glucose', 'BloodPressure', 'BMI', 'DiabetesPedigreeFunction'), ('Glucose', 'BloodPressure', 'BMI', 'Age'), ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI'), ('Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI'), ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'Age'), ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), ('Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction'), ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction', 'Age'), ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction'), ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction', 'Age')]
#
# {'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.5864278926040521}
# {'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction', 'Age'), 'value': 0.5957814598538134}
# ========================================== find best value ===================================
# [{'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction', 'Age'), 'value': 0.5957814598538134}]
# =============================================================================================
#
# ========================================== Subset_Score Round 8 =============================
#
# combination of previous round:===========> [('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'Age'), ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'DiabetesPedigreeFunction', 'Age'), ('Pregnancies', 'Glucose', 'BloodPressure', 'BMI', 'DiabetesPedigreeFunction', 'Age'), ('Pregnancies', 'Glucose', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction', 'Age'), ('Pregnancies', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction', 'Age'), ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction', 'Age')]
# never occured combination:===============> [('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'Age'), ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'DiabetesPedigreeFunction', 'Age'), ('Pregnancies', 'Glucose', 'BloodPressure', 'BMI', 'DiabetesPedigreeFunction', 'Age'), ('Pregnancies', 'Glucose', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction', 'Age'), ('Pregnancies', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction', 'Age')]
#
# ------------------------------------------calculate sbs check------------------------------------------
# {'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'Age'), 'value': 0.583029075808007}
# {'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'DiabetesPedigreeFunction', 'Age'), 'value': 0.5647297770015836}
# {'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age'), 'value': 0.5822786498569632}
# {'attributes': ('Pregnancies', 'Glucose', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age'), 'value': 0.560817327661286}
# {'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction', 'Age'), 'value': 0.5957814598538134}
# {'attributes': ('Pregnancies', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age'), 'value': 0.5663962160481416}
# ========================================== find best value ===================================
# [{'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction', 'Age'), 'value': 0.5957814598538134}]
# =============================================================================================
# sbs check: [{'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction', 'Age'), 'value': 0.5957814598538134}]
# current best [{'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction', 'Age'), 'value': 0.5957814598538134}]
# current best_subset_score -----> [[{'attributes': ('BloodPressure',), 'value': 0.6973898871046167}], [{'attributes': ('BloodPressure', 'BMI'), 'value': 0.6836963144135753}], [{'attributes': ('Glucose', 'BloodPressure', 'BMI'), 'value': 0.6752434324079261}], [{'attributes': ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI'), 'value': 0.6432227322396636}], [{'attributes': ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.6229597158072449}], [{'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), 'value': 0.6087257144119065}], [{'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction', 'Age'), 'value': 0.5957814598538134}]]
# ------------------------------------------calculate sbs check------------------------------------------
#
# combination_hist:=====================> [('Pregnancies', 'BloodPressure'), ('Glucose', 'BloodPressure'), ('BloodPressure', 'SkinThickness'), ('BloodPressure', 'Insulin'), ('BloodPressure', 'BMI'), ('BloodPressure', 'DiabetesPedigreeFunction'), ('BloodPressure', 'Age'), ('Pregnancies', 'BloodPressure', 'BMI'), ('Glucose', 'BloodPressure', 'BMI'), ('BloodPressure', 'SkinThickness', 'BMI'), ('BloodPressure', 'Insulin', 'BMI'), ('BloodPressure', 'BMI', 'DiabetesPedigreeFunction'), ('BloodPressure', 'BMI', 'Age'), ('Pregnancies', 'Glucose', 'BloodPressure', 'BMI'), ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI'), ('Glucose', 'BloodPressure', 'Insulin', 'BMI'), ('Glucose', 'BloodPressure', 'BMI', 'DiabetesPedigreeFunction'), ('Glucose', 'BloodPressure', 'BMI', 'Age'), ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI'), ('Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI'), ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'Age'), ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction'), ('Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction'), ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction', 'Age'), ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction'), ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction', 'Age'), ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age')]
#
# {'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age'), 'value': 0.5778888975917024}
# ========================================== find best value ===================================
# [{'attributes': ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age'), 'value': 0.5778888975917024}]
# =============================================================================================
#
#
# best_subset_per_round :
#  =============== SubsetRanking ===============
# [{'attributes': ('BloodPressure',), 'value': 0.6973898871046167},
#  {'attributes': ('BloodPressure', 'BMI'), 'value': 0.6836963144135753},
#  {'attributes': ('Glucose', 'BloodPressure', 'BMI'),
#   'value': 0.6752434324079261},
#  {'attributes': ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI'),
#   'value': 0.6432227322396636},
#  {'attributes': ('Glucose',
#    'BloodPressure',
#    'SkinThickness',
#    'BMI',
#    'DiabetesPedigreeFunction'),
#   'value': 0.6229597158072449},
#  {'attributes': ('Pregnancies',
#    'Glucose',
#    'BloodPressure',
#    'SkinThickness',
#    'BMI',
#    'DiabetesPedigreeFunction'),
#   'value': 0.6087257144119065},
#  {'attributes': ('Pregnancies',
#    'Glucose',
#    'BloodPressure',
#    'SkinThickness',
#    'BMI',
#    'DiabetesPedigreeFunction',
#    'Age'),
#   'value': 0.5957814598538134},
#  {'attributes': ('Pregnancies',
#    'Glucose',
#    'BloodPressure',
#    'SkinThickness',
#    'Insulin',
#    'BMI',
#    'DiabetesPedigreeFunction',
#    'Age'),
#   'value': 0.5778888975917024}]

# %% [markdown]
# <h2> The Best Candidate Subset by SFS

# %%
find_best_subset(best_subset_per_round, 'max')
# Out:
# ========================================== find best value ===================================
# [{'attributes': ('BloodPressure',), 'value': 0.6973898871046167}]
# =============================================================================================
# [{'attributes': ('BloodPressure',), 'value': 0.6973898871046167}]
