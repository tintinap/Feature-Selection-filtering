# %%
#library
import pandas as pd
import numpy as np
import itertools
import seaborn as sns
import math

# %% [markdown]
# <H1>Dataset : Breast Cancer

# %%
df = pd.read_csv("../dataset/breast_cancer.csv")
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          17.33           184.60      2019.0           0.16220
# 1    ...          23.41           158.80      1956.0           0.12380
# 2    ...          25.53           152.50      1709.0           0.14440
# 3    ...          26.50            98.87       567.7           0.20980
# 4    ...          16.67           152.20      1575.0           0.13740
# ..   ...            ...              ...         ...               ...
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.11890          NaN
# 1                    0.08902          NaN
# 2                    0.08758          NaN
# 3                    0.17300          NaN
# 4                    0.07678          NaN
# ..                       ...          ...
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
#turn M = 1 B = 0
df["diagnosis"] = df['diagnosis'].apply(lambda i : 1 if i == 'M' else 0)
df
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# 1       1326.0          0.08474           0.07864         0.08690
# 2       1203.0          0.10960           0.15990         0.19740
# 3        386.1          0.14250           0.28390         0.24140
# 4       1297.0          0.10030           0.13280         0.19800
# ..         ...              ...               ...             ...
# 564     1479.0          0.11100           0.11590         0.24390
# 565     1261.0          0.09780           0.10340         0.14400
# 566      858.1          0.08455           0.10230         0.09251
# 567     1265.0          0.11780           0.27700         0.35140
# 568      181.0          0.05263           0.04362         0.00000
#
#      concave points_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0                0.14710  ...          17.33           184.60      2019.0
# 1                0.07017  ...          23.41           158.80      1956.0
# 2                0.12790  ...          25.53           152.50      1709.0
# 3                0.10520  ...          26.50            98.87       567.7
# 4                0.10430  ...          16.67           152.20      1575.0
# ..                   ...  ...            ...              ...         ...
# 564              0.13890  ...          26.40           166.10      2027.0
# 565              0.09791  ...          38.25           155.00      1731.0
# 566              0.05302  ...          34.12           126.70      1124.0
# 567              0.15200  ...          39.42           184.60      1821.0
# 568              0.00000  ...          30.37            59.16       268.6
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst  \
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
#      Unnamed: 32
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 564          NaN
# 565          NaN
# 566          NaN
# 567          NaN
# 568          NaN
#
# [569 rows x 33 columns]

# %% [markdown]
# <h1>Features

# %%
features = df.columns.tolist()[2:-1]
features
# Out:
# ['radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'radius_se',
#  'texture_se',
#  'perimeter_se',
#  'area_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave points_se',
#  'symmetry_se',
#  'fractal_dimension_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst',
#  'concave points_worst',
#  'symmetry_worst',
#  'fractal_dimension_worst']

# %%
X = df[features]
X
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 0                   0.07871  ...        25.380          17.33
# 1                   0.05667  ...        24.990          23.41
# 2                   0.05999  ...        23.570          25.53
# 3                   0.09744  ...        14.910          26.50
# 4                   0.05883  ...        22.540          16.67
# ..                      ...  ...           ...            ...
# 564                 0.05623  ...        25.450          26.40
# 565                 0.05533  ...        23.690          38.25
# 566                 0.05648  ...        18.980          34.12
# 567                 0.07016  ...        25.740          39.42
# 568                 0.05884  ...         9.456          30.37
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0             184.60      2019.0           0.16220            0.66560
# 1             158.80      1956.0           0.12380            0.18660
# 2             152.50      1709.0           0.14440            0.42450
# 3              98.87       567.7           0.20980            0.86630
# 4             152.20      1575.0           0.13740            0.20500
# ..               ...         ...               ...                ...
# 564           166.10      2027.0           0.14100            0.21130
# 565           155.00      1731.0           0.11660            0.19220
# 566           126.70      1124.0           0.11390            0.30940
# 567           184.60      1821.0           0.16500            0.86810
# 568            59.16       268.6           0.08996            0.06444
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.7119                0.2654          0.4601
# 1             0.2416                0.1860          0.2750
# 2             0.4504                0.2430          0.3613
# 3             0.6869                0.2575          0.6638
# 4             0.4000                0.1625          0.2364
# ..               ...                   ...             ...
# 564           0.4107                0.2216          0.2060
# 565           0.3215                0.1628          0.2572
# 566           0.3403                0.1418          0.2218
# 567           0.9387                0.2650          0.4087
# 568           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 564                  0.07115
# 565                  0.06637
# 566                  0.07820
# 567                  0.12400
# 568                  0.07039
#
# [569 rows x 30 columns]

# %% [markdown]
# <h2> Normalization Data

# %%
X = df[features].apply(lambda x: (x - x.min()) / (x.max() - x.min()))
X
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       0.521037      0.022658        0.545989   0.363733         0.593753
# 1       0.643144      0.272574        0.615783   0.501591         0.289880
# 2       0.601496      0.390260        0.595743   0.449417         0.514309
# 3       0.210090      0.360839        0.233501   0.102906         0.811321
# 4       0.629893      0.156578        0.630986   0.489290         0.430351
# ..           ...           ...             ...        ...              ...
# 564     0.690000      0.428813        0.678668   0.566490         0.526948
# 565     0.622320      0.626987        0.604036   0.474019         0.407782
# 566     0.455251      0.621238        0.445788   0.303118         0.288165
# 567     0.644564      0.663510        0.665538   0.475716         0.588336
# 568     0.036869      0.501522        0.028540   0.015907         0.000000
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0            0.792037        0.703140             0.731113       0.686364
# 1            0.181768        0.203608             0.348757       0.379798
# 2            0.431017        0.462512             0.635686       0.509596
# 3            0.811361        0.565604             0.522863       0.776263
# 4            0.347893        0.463918             0.518390       0.378283
# ..                ...             ...                  ...            ...
# 564          0.296055        0.571462             0.690358       0.336364
# 565          0.257714        0.337395             0.486630       0.349495
# 566          0.254340        0.216753             0.263519       0.267677
# 567          0.790197        0.823336             0.755467       0.675253
# 568          0.074351        0.000000             0.000000       0.266162
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 0                  0.605518  ...      0.620776       0.141525
# 1                  0.141323  ...      0.606901       0.303571
# 2                  0.211247  ...      0.556386       0.360075
# 3                  1.000000  ...      0.248310       0.385928
# 4                  0.186816  ...      0.519744       0.123934
# ..                      ...  ...           ...            ...
# 564                0.132056  ...      0.623266       0.383262
# 565                0.113100  ...      0.560655       0.699094
# 566                0.137321  ...      0.393099       0.589019
# 567                0.425442  ...      0.633582       0.730277
# 568                0.187026  ...      0.054287       0.489072
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0           0.668310    0.450698          0.601136           0.619292
# 1           0.539818    0.435214          0.347553           0.154563
# 2           0.508442    0.374508          0.483590           0.385375
# 3           0.241347    0.094008          0.915472           0.814012
# 4           0.506948    0.341575          0.437364           0.172415
# ..               ...         ...               ...                ...
# 564         0.576174    0.452664          0.461137           0.178527
# 565         0.520892    0.379915          0.300007           0.159997
# 566         0.379949    0.230731          0.282177           0.273705
# 567         0.668310    0.402035          0.619626           0.815758
# 568         0.043578    0.020497          0.124084           0.036043
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 0           0.568610              0.912027        0.598462
# 1           0.192971              0.639175        0.233590
# 2           0.359744              0.835052        0.403706
# 3           0.548642              0.884880        1.000000
# 4           0.319489              0.558419        0.157500
# ..               ...                   ...             ...
# 564         0.328035              0.761512        0.097575
# 565         0.256789              0.559450        0.198502
# 566         0.271805              0.487285        0.128721
# 567         0.749760              0.910653        0.497142
# 568         0.000000              0.000000        0.257441
#
#      fractal_dimension_worst
# 0                   0.418864
# 1                   0.222878
# 2                   0.213433
# 3                   0.773711
# 4                   0.142595
# ..                       ...
# 564                 0.105667
# 565                 0.074315
# 566                 0.151909
# 567                 0.452315
# 568                 0.100682
#
# [569 rows x 30 columns]

# %%
label = 'diagnosis'
label
# Out:
# 'diagnosis'

# %%
y = df['diagnosis']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int64

# %%
num_feats = X.shape[1]
num_feats
# Out:
# 30

# %% [markdown]
# <h2> Euclidean Distance Table

# %%
df_ed = {label: []}

for f in features:
    df_ed[label].append(np.mean([math.sqrt((a[0]-a[1])**2) for a in zip(X[f], y)]))

df_ed = pd.DataFrame.from_dict(df_ed)
df_ed.index = features
df_ed
# Out:
#                          diagnosis
# radius_mean               0.341138
# texture_mean              0.396796
# perimeter_mean            0.336950
# area_mean                 0.325613
# smoothness_mean           0.429204
# compactness_mean          0.345632
# concavity_mean            0.299939
# concave points_mean       0.289839
# symmetry_mean             0.425110
# fractal_dimension_mean    0.443329
# radius_se                 0.344660
# texture_se                0.421808
# perimeter_se              0.346720
# area_se                   0.343541
# smoothness_se             0.425347
# compactness_se            0.378963
# concavity_se              0.374421
# concave points_se         0.383449
# symmetry_se               0.418713
# fractal_dimension_se      0.391229
# radius_worst              0.319200
# texture_worst             0.393030
# perimeter_worst           0.318151
# area_worst                0.316928
# smoothness_worst          0.414175
# compactness_worst         0.341541
# concavity_worst           0.321794
# concave points_worst      0.299762
# symmetry_worst            0.390633
# fractal_dimension_worst   0.383830

# %% [markdown]
# <h1> Function

# %%
def grouping_attribute_score(attrubutes, value):
    '''combine value to dictionary format'''
    return {"attributes": attrubutes, "value": value}
#can modify to be object in the future

# %%
def find_best_subset(subset_score, max_min='max'):
    """find best score of subset subset score is list of grouping_attribute_score
        max_min (str) : can be only 'max' or 'min' to define the best value
    """
    #still available for only a group of attributes
    print('========================================== find best value ===================================')
    best_subset_score = []
    
    if max_min == 'min':
        # min is the best
        subset_score.sort(key=lambda x: x['value'], reverse=False)
    else:        
        #max is the best
        subset_score.sort(key=lambda x: x['value'], reverse=True)

    best_subset_score.append(subset_score[0])
    print(best_subset_score)
    print("=============================================================================================")
    return best_subset_score
# return [{'attrubute': ('Glucose', 'BMI'), 'value': 0.3796380304756596}]

# %%
def cal_best(algo_round, max_min='max'):
    """match all subset and find the best one
        max_min (str) : can be only 'max' or 'min' to define the best value
    """
    #start calculating
    subset_score = []
    subset_mean = []
    
    #use mean of all euclidean distance subset
    for atrs in algo_round:
        temp_score_mean = []
        for i in atrs:
            #euclidean distance
            ed = df_ed[label][i]
            temp_score_mean.append(ed)
        subset_mean.append(np.mean(temp_score_mean)) #score
        
    for atrs,mean_score in zip(algo_round,subset_mean):
        subset_score.append(grouping_attribute_score(atrs, mean_score))
    [print(i) for i in subset_score]
    return find_best_subset(subset_score=subset_score, max_min=max_min)

# %% [markdown]
# <h1>SFFS

# %%
import time
start_time = time.time()

best_subset_per_round = []
combination_history = []
for num in range(1, num_feats+1):   
    print("========================================== Subset_Score Round", num,'=============================')
    if num == 1: #1st round
        #combination of subset in each round
        sfs_round = list(itertools.combinations(features, num))

        print()        
        best_subset_per_round.append(cal_best(algo_round=sfs_round, max_min='max'))
        print()
        
    elif num == 2 or num == 3:
        #combination of subset in each round
        sfs_round = list(itertools.combinations(features, num))
        
        #hv to pop non-best_subset out
        sfs_round_temp = []
        for i in range(len(sfs_round)):
            if all(attr in sfs_round[i] for attr in best_subset_per_round[num-2][0]['attributes']):
                sfs_round_temp.append(sfs_round[i])
        sfs_round = sfs_round_temp
        #record the history of combination
        combination_history.extend(sfs_round)
        print('combination_hist:=====================>', combination_history)
        
        print()
        best_subset_per_round.append(cal_best(algo_round=sfs_round, max_min='max'))
        print()
        
    else: #other round
        print()
        #combination
        sfs_check = list(itertools.combinations(best_subset_per_round[-1][0]['attributes'], num-2))
        print('combination of previous round:===========>', sfs_check)
        #check history
        [sfs_check.remove(i) for i in sfs_check if i in combination_history]
                
        print('never occured combination:===============>', sfs_check)
        #combination in the same number as last round that has sfs_check inside
        check_temp = []
        comb_temp = list(itertools.combinations(features, num-1))
        for j in range(len(sfs_check)):
            for i in range(len(comb_temp)):
                if all(attr in comb_temp[i] for attr in sfs_check[j]):
                    check_temp.append(comb_temp[i])
        comb_temp = check_temp
        #check history
        [comb_temp.remove(i) for i in comb_temp if i in combination_history]
        print()
        print('------------------------------------------calculate sbs check------------------------------------------')
        sbs_check = cal_best(comb_temp)
        print('sbs check:',sbs_check)
        print('current best', best_subset_per_round[-1])
        if sbs_check[0]['value'] > best_subset_per_round[-1][0]['value']: #max is the best
            print('privoue best_subset_score ----->', best_subset_per_round)
            print('new value')
            best_subset_per_round[-1][0] = sbs_check[0]
        print('current best_subset_score ----->', best_subset_per_round)
        print('------------------------------------------calculate sbs check------------------------------------------')
        print()
        sfs_round = list(itertools.combinations(features, num))
        
        #hv to pop non-best_subset out
        sfs_round_temp = []
        for i in range(len(sfs_round)):
            if all(attr in sfs_round[i] for attr in best_subset_per_round[num-2][0]['attributes']):
                sfs_round_temp.append(sfs_round[i])
        sfs_round = sfs_round_temp
        #record the history of combination
        combination_history.extend(sfs_round)
        print('combination_hist:=====================>', combination_history)
        
        print()
        best_subset_per_round.append(cal_best(algo_round=sfs_round, max_min='max'))
        print()       
        
print()
print('best_subset_per_round :',"\n", '=============== SubsetRanking ===============')
# [print(i) for i in best_subset_per_round]

best_temp = [i[0] for i in best_subset_per_round]
best_subset_per_round = best_temp
best_subset_per_round.sort(key=lambda x: x['value'], reverse=True) # max is the best
print('+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++')
print("--- %s seconds ---" % (time.time() - start_time))
print('+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++')
best_subset_per_round
# Out:
# ========================================== Subset_Score Round 1 =============================
#
# {'attributes': ('radius_mean',), 'value': 0.3411375148774359}
# {'attributes': ('texture_mean',), 'value': 0.3967957835002344}
# {'attributes': ('perimeter_mean',), 'value': 0.33694964014447903}
# {'attributes': ('area_mean',), 'value': 0.3256128684768165}
# {'attributes': ('smoothness_mean',), 'value': 0.4292040712615145}
# {'attributes': ('compactness_mean',), 'value': 0.34563170081643996}
# {'attributes': ('concavity_mean',), 'value': 0.29993893617932443}
# {'attributes': ('concave points_mean',), 'value': 0.28983946933513155}
# {'attributes': ('symmetry_mean',), 'value': 0.4251096199250856}
# {'attributes': ('fractal_dimension_mean',), 'value': 0.44332939000863186}
# {'attributes': ('radius_se',), 'value': 0.344660243296367}
# {'attributes': ('texture_se',), 'value': 0.42180753350253425}
# {'attributes': ('perimeter_se',), 'value': 0.34672009600619813}
# {'attributes': ('area_se',), 'value': 0.34354084080649533}
# {'attributes': ('smoothness_se',), 'value': 0.42534710719558705}
# {'attributes': ('compactness_se',), 'value': 0.3789628259906929}
# {'attributes': ('concavity_se',), 'value': 0.3744214757415988}
# {'attributes': ('concave points_se',), 'value': 0.3834486280653756}
# {'attributes': ('symmetry_se',), 'value': 0.41871321439413506}
# {'attributes': ('fractal_dimension_se',), 'value': 0.3912293619162343}
# {'attributes': ('radius_worst',), 'value': 0.31920036712413385}
# {'attributes': ('texture_worst',), 'value': 0.39303045405660625}
# {'attributes': ('perimeter_worst',), 'value': 0.31815138638231355}
# {'attributes': ('area_worst',), 'value': 0.3169275802419821}
# {'attributes': ('smoothness_worst',), 'value': 0.4141752550697991}
# {'attributes': ('compactness_worst',), 'value': 0.3415409095977129}
# {'attributes': ('concavity_worst',), 'value': 0.32179442522894824}
# {'attributes': ('concave points_worst',), 'value': 0.2997621739471793}
# {'attributes': ('symmetry_worst',), 'value': 0.39063313583023535}
# {'attributes': ('fractal_dimension_worst',), 'value': 0.3838304299240551}
# ========================================== find best value ===================================
# [{'attributes': ('fractal_dimension_mean',), 'value': 0.44332939000863186}]
# =============================================================================================
#
# ========================================== Subset_Score Round 2 =============================
# combination_hist:=====================> [('radius_mean', 'fractal_dimension_mean'), ('texture_mean', 'fractal_dimension_mean'), ('perimeter_mean', 'fractal_dimension_mean'), ('area_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'fractal_dimension_mean'), ('compactness_mean', 'fractal_dimension_mean'), ('concavity_mean', 'fractal_dimension_mean'), ('concave points_mean', 'fractal_dimension_mean'), ('symmetry_mean', 'fractal_dimension_mean'), ('fractal_dimension_mean', 'radius_se'), ('fractal_dimension_mean', 'texture_se'), ('fractal_dimension_mean', 'perimeter_se'), ('fractal_dimension_mean', 'area_se'), ('fractal_dimension_mean', 'smoothness_se'), ('fractal_dimension_mean', 'compactness_se'), ('fractal_dimension_mean', 'concavity_se'), ('fractal_dimension_mean', 'concave points_se'), ('fractal_dimension_mean', 'symmetry_se'), ('fractal_dimension_mean', 'fractal_dimension_se'), ('fractal_dimension_mean', 'radius_worst'), ('fractal_dimension_mean', 'texture_worst'), ('fractal_dimension_mean', 'perimeter_worst'), ('fractal_dimension_mean', 'area_worst'), ('fractal_dimension_mean', 'smoothness_worst'), ('fractal_dimension_mean', 'compactness_worst'), ('fractal_dimension_mean', 'concavity_worst'), ('fractal_dimension_mean', 'concave points_worst'), ('fractal_dimension_mean', 'symmetry_worst'), ('fractal_dimension_mean', 'fractal_dimension_worst')]
#
# {'attributes': ('radius_mean', 'fractal_dimension_mean'), 'value': 0.39223345244303387}
# {'attributes': ('texture_mean', 'fractal_dimension_mean'), 'value': 0.42006258675443314}
# {'attributes': ('perimeter_mean', 'fractal_dimension_mean'), 'value': 0.3901395150765554}
# {'attributes': ('area_mean', 'fractal_dimension_mean'), 'value': 0.3844711292427242}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean'), 'value': 0.43626673063507315}
# {'attributes': ('compactness_mean', 'fractal_dimension_mean'), 'value': 0.3944805454125359}
# {'attributes': ('concavity_mean', 'fractal_dimension_mean'), 'value': 0.3716341630939781}
# {'attributes': ('concave points_mean', 'fractal_dimension_mean'), 'value': 0.3665844296718817}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean'), 'value': 0.43421950496685874}
# {'attributes': ('fractal_dimension_mean', 'radius_se'), 'value': 0.39399481665249947}
# {'attributes': ('fractal_dimension_mean', 'texture_se'), 'value': 0.43256846175558306}
# {'attributes': ('fractal_dimension_mean', 'perimeter_se'), 'value': 0.39502474300741497}
# {'attributes': ('fractal_dimension_mean', 'area_se'), 'value': 0.3934351154075636}
# {'attributes': ('fractal_dimension_mean', 'smoothness_se'), 'value': 0.43433824860210946}
# {'attributes': ('fractal_dimension_mean', 'compactness_se'), 'value': 0.4111461079996624}
# {'attributes': ('fractal_dimension_mean', 'concavity_se'), 'value': 0.4088754328751153}
# {'attributes': ('fractal_dimension_mean', 'concave points_se'), 'value': 0.4133890090370037}
# {'attributes': ('fractal_dimension_mean', 'symmetry_se'), 'value': 0.43102130220138346}
# {'attributes': ('fractal_dimension_mean', 'fractal_dimension_se'), 'value': 0.4172793759624331}
# {'attributes': ('fractal_dimension_mean', 'radius_worst'), 'value': 0.38126487856638286}
# {'attributes': ('fractal_dimension_mean', 'texture_worst'), 'value': 0.41817992203261906}
# {'attributes': ('fractal_dimension_mean', 'perimeter_worst'), 'value': 0.38074038819547273}
# {'attributes': ('fractal_dimension_mean', 'area_worst'), 'value': 0.38012848512530695}
# {'attributes': ('fractal_dimension_mean', 'smoothness_worst'), 'value': 0.42875232253921547}
# {'attributes': ('fractal_dimension_mean', 'compactness_worst'), 'value': 0.3924351498031724}
# {'attributes': ('fractal_dimension_mean', 'concavity_worst'), 'value': 0.38256190761879005}
# {'attributes': ('fractal_dimension_mean', 'concave points_worst'), 'value': 0.37154578197790555}
# {'attributes': ('fractal_dimension_mean', 'symmetry_worst'), 'value': 0.4169812629194336}
# {'attributes': ('fractal_dimension_mean', 'fractal_dimension_worst'), 'value': 0.4135799099663435}
# ========================================== find best value ===================================
# [{'attributes': ('smoothness_mean', 'fractal_dimension_mean'), 'value': 0.43626673063507315}]
# =============================================================================================
#
# ========================================== Subset_Score Round 3 =============================
# combination_hist:=====================> [('radius_mean', 'fractal_dimension_mean'), ('texture_mean', 'fractal_dimension_mean'), ('perimeter_mean', 'fractal_dimension_mean'), ('area_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'fractal_dimension_mean'), ('compactness_mean', 'fractal_dimension_mean'), ('concavity_mean', 'fractal_dimension_mean'), ('concave points_mean', 'fractal_dimension_mean'), ('symmetry_mean', 'fractal_dimension_mean'), ('fractal_dimension_mean', 'radius_se'), ('fractal_dimension_mean', 'texture_se'), ('fractal_dimension_mean', 'perimeter_se'), ('fractal_dimension_mean', 'area_se'), ('fractal_dimension_mean', 'smoothness_se'), ('fractal_dimension_mean', 'compactness_se'), ('fractal_dimension_mean', 'concavity_se'), ('fractal_dimension_mean', 'concave points_se'), ('fractal_dimension_mean', 'symmetry_se'), ('fractal_dimension_mean', 'fractal_dimension_se'), ('fractal_dimension_mean', 'radius_worst'), ('fractal_dimension_mean', 'texture_worst'), ('fractal_dimension_mean', 'perimeter_worst'), ('fractal_dimension_mean', 'area_worst'), ('fractal_dimension_mean', 'smoothness_worst'), ('fractal_dimension_mean', 'compactness_worst'), ('fractal_dimension_mean', 'concavity_worst'), ('fractal_dimension_mean', 'concave points_worst'), ('fractal_dimension_mean', 'symmetry_worst'), ('fractal_dimension_mean', 'fractal_dimension_worst'), ('radius_mean', 'smoothness_mean', 'fractal_dimension_mean'), ('texture_mean', 'smoothness_mean', 'fractal_dimension_mean'), ('perimeter_mean', 'smoothness_mean', 'fractal_dimension_mean'), ('area_mean', 'smoothness_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'compactness_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'concavity_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'concave points_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'fractal_dimension_mean', 'radius_se'), ('smoothness_mean', 'fractal_dimension_mean', 'texture_se'), ('smoothness_mean', 'fractal_dimension_mean', 'perimeter_se'), ('smoothness_mean', 'fractal_dimension_mean', 'area_se'), ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se'), ('smoothness_mean', 'fractal_dimension_mean', 'compactness_se'), ('smoothness_mean', 'fractal_dimension_mean', 'concavity_se'), ('smoothness_mean', 'fractal_dimension_mean', 'concave points_se'), ('smoothness_mean', 'fractal_dimension_mean', 'symmetry_se'), ('smoothness_mean', 'fractal_dimension_mean', 'fractal_dimension_se'), ('smoothness_mean', 'fractal_dimension_mean', 'radius_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'texture_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'perimeter_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'area_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'compactness_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'concavity_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'concave points_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'symmetry_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'fractal_dimension_worst')]
#
# {'attributes': ('radius_mean', 'smoothness_mean', 'fractal_dimension_mean'), 'value': 0.4045569920491941}
# {'attributes': ('texture_mean', 'smoothness_mean', 'fractal_dimension_mean'), 'value': 0.4231097482567936}
# {'attributes': ('perimeter_mean', 'smoothness_mean', 'fractal_dimension_mean'), 'value': 0.40316103380487517}
# {'attributes': ('area_mean', 'smoothness_mean', 'fractal_dimension_mean'), 'value': 0.39938210991565426}
# {'attributes': ('smoothness_mean', 'compactness_mean', 'fractal_dimension_mean'), 'value': 0.4060550540288621}
# {'attributes': ('smoothness_mean', 'concavity_mean', 'fractal_dimension_mean'), 'value': 0.39082413248315695}
# {'attributes': ('smoothness_mean', 'concave points_mean', 'fractal_dimension_mean'), 'value': 0.38745764353509266}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.432547693731744}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'radius_se'), 'value': 0.40573123485550444}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'texture_se'), 'value': 0.43144699825756017}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'perimeter_se'), 'value': 0.4064178524254481}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'area_se'), 'value': 0.40535810069221384}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.43262685615524443}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'compactness_se'), 'value': 0.4171654290869464}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'concavity_se'), 'value': 0.4156516456705817}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'concave points_se'), 'value': 0.418660696445174}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'symmetry_se'), 'value': 0.43041555855476044}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'fractal_dimension_se'), 'value': 0.4212542743954602}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'radius_worst'), 'value': 0.3972446094647601}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'texture_worst'), 'value': 0.42185463844225085}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'perimeter_worst'), 'value': 0.39689494921748664}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'area_worst'), 'value': 0.39648701383737617}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.42890290544664844}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'compactness_worst'), 'value': 0.40469145695595304}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'concavity_worst'), 'value': 0.39810929549969815}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'concave points_worst'), 'value': 0.3907652117391085}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'symmetry_worst'), 'value': 0.4210555323667939}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'fractal_dimension_worst'), 'value': 0.4187879637314005}
# ========================================== find best value ===================================
# [{'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.43262685615524443}]
# =============================================================================================
#
# ========================================== Subset_Score Round 4 =============================
#
# combination of previous round:===========> [('smoothness_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'smoothness_se'), ('fractal_dimension_mean', 'smoothness_se')]
# never occured combination:===============> [('smoothness_mean', 'smoothness_se')]
#
# ------------------------------------------calculate sbs check------------------------------------------
# {'attributes': ('radius_mean', 'smoothness_mean', 'smoothness_se'), 'value': 0.39856289777817916}
# {'attributes': ('texture_mean', 'smoothness_mean', 'smoothness_se'), 'value': 0.4171156539857786}
# {'attributes': ('perimeter_mean', 'smoothness_mean', 'smoothness_se'), 'value': 0.3971669395338602}
# {'attributes': ('area_mean', 'smoothness_mean', 'smoothness_se'), 'value': 0.3933880156446394}
# {'attributes': ('smoothness_mean', 'compactness_mean', 'smoothness_se'), 'value': 0.4000609597578471}
# {'attributes': ('smoothness_mean', 'concavity_mean', 'smoothness_se'), 'value': 0.38483003821214196}
# {'attributes': ('smoothness_mean', 'concave points_mean', 'smoothness_se'), 'value': 0.38146354926407766}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_se'), 'value': 0.426553599460729}
# {'attributes': ('smoothness_mean', 'radius_se', 'smoothness_se'), 'value': 0.39973714058448956}
# {'attributes': ('smoothness_mean', 'texture_se', 'smoothness_se'), 'value': 0.4254529039865453}
# {'attributes': ('smoothness_mean', 'perimeter_se', 'smoothness_se'), 'value': 0.4004237581544332}
# {'attributes': ('smoothness_mean', 'area_se', 'smoothness_se'), 'value': 0.39936400642119896}
# {'attributes': ('smoothness_mean', 'smoothness_se', 'compactness_se'), 'value': 0.41117133481593154}
# {'attributes': ('smoothness_mean', 'smoothness_se', 'concavity_se'), 'value': 0.4096575513995668}
# {'attributes': ('smoothness_mean', 'smoothness_se', 'concave points_se'), 'value': 0.412666602174159}
# {'attributes': ('smoothness_mean', 'smoothness_se', 'symmetry_se'), 'value': 0.42442146428374555}
# {'attributes': ('smoothness_mean', 'smoothness_se', 'fractal_dimension_se'), 'value': 0.4152601801244453}
# {'attributes': ('smoothness_mean', 'smoothness_se', 'radius_worst'), 'value': 0.39125051519374515}
# {'attributes': ('smoothness_mean', 'smoothness_se', 'texture_worst'), 'value': 0.41586054417123597}
# {'attributes': ('smoothness_mean', 'smoothness_se', 'perimeter_worst'), 'value': 0.3909008549464717}
# {'attributes': ('smoothness_mean', 'smoothness_se', 'area_worst'), 'value': 0.3904929195663612}
# {'attributes': ('smoothness_mean', 'smoothness_se', 'smoothness_worst'), 'value': 0.42290881117563356}
# {'attributes': ('smoothness_mean', 'smoothness_se', 'compactness_worst'), 'value': 0.39869736268493816}
# {'attributes': ('smoothness_mean', 'smoothness_se', 'concavity_worst'), 'value': 0.39211520122868326}
# {'attributes': ('smoothness_mean', 'smoothness_se', 'concave points_worst'), 'value': 0.38477111746809367}
# {'attributes': ('smoothness_mean', 'smoothness_se', 'symmetry_worst'), 'value': 0.41506143809577895}
# {'attributes': ('smoothness_mean', 'smoothness_se', 'fractal_dimension_worst'), 'value': 0.4127938694603856}
# ========================================== find best value ===================================
# [{'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_se'), 'value': 0.426553599460729}]
# =============================================================================================
# sbs check: [{'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_se'), 'value': 0.426553599460729}]
# current best [{'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.43262685615524443}]
# current best_subset_score -----> [[{'attributes': ('fractal_dimension_mean',), 'value': 0.44332939000863186}], [{'attributes': ('smoothness_mean', 'fractal_dimension_mean'), 'value': 0.43626673063507315}], [{'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.43262685615524443}]]
# ------------------------------------------calculate sbs check------------------------------------------
#
# combination_hist:=====================> [('radius_mean', 'fractal_dimension_mean'), ('texture_mean', 'fractal_dimension_mean'), ('perimeter_mean', 'fractal_dimension_mean'), ('area_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'fractal_dimension_mean'), ('compactness_mean', 'fractal_dimension_mean'), ('concavity_mean', 'fractal_dimension_mean'), ('concave points_mean', 'fractal_dimension_mean'), ('symmetry_mean', 'fractal_dimension_mean'), ('fractal_dimension_mean', 'radius_se'), ('fractal_dimension_mean', 'texture_se'), ('fractal_dimension_mean', 'perimeter_se'), ('fractal_dimension_mean', 'area_se'), ('fractal_dimension_mean', 'smoothness_se'), ('fractal_dimension_mean', 'compactness_se'), ('fractal_dimension_mean', 'concavity_se'), ('fractal_dimension_mean', 'concave points_se'), ('fractal_dimension_mean', 'symmetry_se'), ('fractal_dimension_mean', 'fractal_dimension_se'), ('fractal_dimension_mean', 'radius_worst'), ('fractal_dimension_mean', 'texture_worst'), ('fractal_dimension_mean', 'perimeter_worst'), ('fractal_dimension_mean', 'area_worst'), ('fractal_dimension_mean', 'smoothness_worst'), ('fractal_dimension_mean', 'compactness_worst'), ('fractal_dimension_mean', 'concavity_worst'), ('fractal_dimension_mean', 'concave points_worst'), ('fractal_dimension_mean', 'symmetry_worst'), ('fractal_dimension_mean', 'fractal_dimension_worst'), ('radius_mean', 'smoothness_mean', 'fractal_dimension_mean'), ('texture_mean', 'smoothness_mean', 'fractal_dimension_mean'), ('perimeter_mean', 'smoothness_mean', 'fractal_dimension_mean'), ('area_mean', 'smoothness_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'compactness_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'concavity_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'concave points_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'fractal_dimension_mean', 'radius_se'), ('smoothness_mean', 'fractal_dimension_mean', 'texture_se'), ('smoothness_mean', 'fractal_dimension_mean', 'perimeter_se'), ('smoothness_mean', 'fractal_dimension_mean', 'area_se'), ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se'), ('smoothness_mean', 'fractal_dimension_mean', 'compactness_se'), ('smoothness_mean', 'fractal_dimension_mean', 'concavity_se'), ('smoothness_mean', 'fractal_dimension_mean', 'concave points_se'), ('smoothness_mean', 'fractal_dimension_mean', 'symmetry_se'), ('smoothness_mean', 'fractal_dimension_mean', 'fractal_dimension_se'), ('smoothness_mean', 'fractal_dimension_mean', 'radius_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'texture_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'perimeter_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'area_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'compactness_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'concavity_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'concave points_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'symmetry_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'fractal_dimension_worst'), ('radius_mean', 'smoothness_mean', 'fractal_dimension_mean', 'smoothness_se'), ('texture_mean', 'smoothness_mean', 'fractal_dimension_mean', 'smoothness_se'), ('perimeter_mean', 'smoothness_mean', 'fractal_dimension_mean', 'smoothness_se'), ('area_mean', 'smoothness_mean', 'fractal_dimension_mean', 'smoothness_se'), ('smoothness_mean', 'compactness_mean', 'fractal_dimension_mean', 'smoothness_se'), ('smoothness_mean', 'concavity_mean', 'fractal_dimension_mean', 'smoothness_se'), ('smoothness_mean', 'concave points_mean', 'fractal_dimension_mean', 'smoothness_se'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), ('smoothness_mean', 'fractal_dimension_mean', 'radius_se', 'smoothness_se'), ('smoothness_mean', 'fractal_dimension_mean', 'texture_se', 'smoothness_se'), ('smo ...
#
# {'attributes': ('radius_mean', 'smoothness_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.40975452083579234}
# {'attributes': ('texture_mean', 'smoothness_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.42366908799149194}
# {'attributes': ('perimeter_mean', 'smoothness_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.4087075521525531}
# {'attributes': ('area_mean', 'smoothness_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.40587335923563744}
# {'attributes': ('smoothness_mean', 'compactness_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.4108780673205433}
# {'attributes': ('smoothness_mean', 'concavity_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.39945487616126446}
# {'attributes': ('smoothness_mean', 'concave points_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.3969300094502162}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.43074754709770474}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'radius_se', 'smoothness_se'), 'value': 0.4106352029405251}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'texture_se', 'smoothness_se'), 'value': 0.4299220254920669}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'perimeter_se', 'smoothness_se'), 'value': 0.41115016611798283}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'area_se', 'smoothness_se'), 'value': 0.41035535231805714}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se', 'compactness_se'), 'value': 0.41921084861410657}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se', 'concavity_se'), 'value': 0.41807551105183305}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se', 'concave points_se'), 'value': 0.42033229913277725}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se', 'symmetry_se'), 'value': 0.4291484457149671}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se', 'fractal_dimension_se'), 'value': 0.4222774825954919}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se', 'radius_worst'), 'value': 0.4042702338974668}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se', 'texture_worst'), 'value': 0.4227277556305849}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se', 'perimeter_worst'), 'value': 0.4040079887120117}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se', 'area_worst'), 'value': 0.4037020371769289}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se', 'smoothness_worst'), 'value': 0.4280139558838831}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se', 'compactness_worst'), 'value': 0.40985536951586155}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se', 'concavity_worst'), 'value': 0.40491874842367037}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se', 'concave points_worst'), 'value': 0.3994106856032281}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se', 'symmetry_worst'), 'value': 0.42212842607399215}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se', 'fractal_dimension_worst'), 'value': 0.4204277495974471}
# ========================================== find best value ===================================
# [{'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.43074754709770474}]
# =============================================================================================
#
# ========================================== Subset_Score Round 5 =============================
#
# combination of previous round:===========> [('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'symmetry_mean', 'smoothness_se'), ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se'), ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_se')]
# never occured combination:===============> [('smoothness_mean', 'symmetry_mean', 'smoothness_se'), ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_se')]
#
# ------------------------------------------calculate sbs check------------------------------------------
# {'attributes': ('radius_mean', 'smoothness_mean', 'symmetry_mean', 'smoothness_se'), 'value': 0.4051995783149058}
# {'attributes': ('texture_mean', 'smoothness_mean', 'symmetry_mean', 'smoothness_se'), 'value': 0.4191141454706054}
# {'attributes': ('perimeter_mean', 'smoothness_mean', 'symmetry_mean', 'smoothness_se'), 'value': 0.40415260963166655}
# {'attributes': ('area_mean', 'smoothness_mean', 'symmetry_mean', 'smoothness_se'), 'value': 0.4013184167147509}
# {'attributes': ('smoothness_mean', 'compactness_mean', 'symmetry_mean', 'smoothness_se'), 'value': 0.40632312479965677}
# {'attributes': ('smoothness_mean', 'concavity_mean', 'symmetry_mean', 'smoothness_se'), 'value': 0.3948999336403779}
# {'attributes': ('smoothness_mean', 'concave points_mean', 'symmetry_mean', 'smoothness_se'), 'value': 0.39237506692932966}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'radius_se', 'smoothness_se'), 'value': 0.4060802604196385}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'texture_se', 'smoothness_se'), 'value': 0.4253670829711803}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'perimeter_se', 'smoothness_se'), 'value': 0.4065952235970963}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'area_se', 'smoothness_se'), 'value': 0.4058004097971706}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_se', 'compactness_se'), 'value': 0.41465590609322}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_se', 'concavity_se'), 'value': 0.41352056853094643}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_se', 'concave points_se'), 'value': 0.41577735661189064}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_se', 'symmetry_se'), 'value': 0.4245935031940805}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_se', 'fractal_dimension_se'), 'value': 0.41772254007460535}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_se', 'radius_worst'), 'value': 0.39971529137658024}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_se', 'texture_worst'), 'value': 0.41817281310969834}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_se', 'perimeter_worst'), 'value': 0.39945304619112515}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_se', 'area_worst'), 'value': 0.39914709465604226}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_se', 'smoothness_worst'), 'value': 0.4234590133629965}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_se', 'compactness_worst'), 'value': 0.405300426994975}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_se', 'concavity_worst'), 'value': 0.4003638059027838}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_se', 'concave points_worst'), 'value': 0.3948557430823416}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_se', 'symmetry_worst'), 'value': 0.4175734835531056}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_se', 'fractal_dimension_worst'), 'value': 0.41587280707656055}
# {'attributes': ('radius_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.4087309080016851}
# {'attributes': ('texture_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.4226454751573847}
# {'attributes': ('perimeter_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.4076839393184459}
# {'attributes': ('area_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.40484974640153026}
# {'attributes': ('compactness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.4098544544864361}
# {'attributes': ('concavity_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.3984312633271572}
# {'attributes': ('concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.395906396616109}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'smoothness_se'), 'value': 0.4096115901064179}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'smoothness_se'), 'value': 0.4288984126579597}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'perimeter_se', 'smoothness_se'), 'value': 0.41012655328387565}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'area_se', 'smoothness_se'), 'value': 0.40933173948394996}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'compactness_se'), 'value': 0.4181872357799994}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'concavity_se'), 'value': 0.4170518982177258}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'concave points_se'), 'value': 0.41930868629867}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'symmetry_se'), 'value': 0.4281248328808599}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'fractal_dimension_se'), 'value': 0.42125386976138474}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'radius_worst'), 'value': 0.4032466210633596}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'texture_worst'), 'value': 0.4217041427964777}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'perimeter_worst'), 'value': 0.40298437587790453}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'area_worst'), 'value': 0.40267842434282164}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'smoothness_worst'), 'value': 0.4269903430497759}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'compactness_worst'), 'value': 0.40883175668175437}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'concavity_worst'), 'value': 0.4038951355895632}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'concave points_worst'), 'value': 0.398387072769121}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'symmetry_worst'), 'value': 0.42110481323988497}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'fractal_dimension_worst'), 'value': 0.41940413676333993}
# ========================================== find best value ===================================
# [{'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'smoothness_se'), 'value': 0.4288984126579597}]
# =============================================================================================
# sbs check: [{'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'smoothness_se'), 'value': 0.4288984126579597}]
# current best [{'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.43074754709770474}]
# current best_subset_score -----> [[{'attributes': ('fractal_dimension_mean',), 'value': 0.44332939000863186}], [{'attributes': ('smoothness_mean', 'fractal_dimension_mean'), 'value': 0.43626673063507315}], [{'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.43262685615524443}], [{'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.43074754709770474}]]
# ------------------------------------------calculate sbs check------------------------------------------
#
# combination_hist:=====================> [('radius_mean', 'fractal_dimension_mean'), ('texture_mean', 'fractal_dimension_mean'), ('perimeter_mean', 'fractal_dimension_mean'), ('area_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'fractal_dimension_mean'), ('compactness_mean', 'fractal_dimension_mean'), ('concavity_mean', 'fractal_dimension_mean'), ('concave points_mean', 'fractal_dimension_mean'), ('symmetry_mean', 'fractal_dimension_mean'), ('fractal_dimension_mean', 'radius_se'), ('fractal_dimension_mean', 'texture_se'), ('fractal_dimension_mean', 'perimeter_se'), ('fractal_dimension_mean', 'area_se'), ('fractal_dimension_mean', 'smoothness_se'), ('fractal_dimension_mean', 'compactness_se'), ('fractal_dimension_mean', 'concavity_se'), ('fractal_dimension_mean', 'concave points_se'), ('fractal_dimension_mean', 'symmetry_se'), ('fractal_dimension_mean', 'fractal_dimension_se'), ('fractal_dimension_mean', 'radius_worst'), ('fractal_dimension_mean', 'texture_worst'), ('fractal_dimension_mean', 'perimeter_worst'), ('fractal_dimension_mean', 'area_worst'), ('fractal_dimension_mean', 'smoothness_worst'), ('fractal_dimension_mean', 'compactness_worst'), ('fractal_dimension_mean', 'concavity_worst'), ('fractal_dimension_mean', 'concave points_worst'), ('fractal_dimension_mean', 'symmetry_worst'), ('fractal_dimension_mean', 'fractal_dimension_worst'), ('radius_mean', 'smoothness_mean', 'fractal_dimension_mean'), ('texture_mean', 'smoothness_mean', 'fractal_dimension_mean'), ('perimeter_mean', 'smoothness_mean', 'fractal_dimension_mean'), ('area_mean', 'smoothness_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'compactness_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'concavity_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'concave points_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'fractal_dimension_mean', 'radius_se'), ('smoothness_mean', 'fractal_dimension_mean', 'texture_se'), ('smoothness_mean', 'fractal_dimension_mean', 'perimeter_se'), ('smoothness_mean', 'fractal_dimension_mean', 'area_se'), ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se'), ('smoothness_mean', 'fractal_dimension_mean', 'compactness_se'), ('smoothness_mean', 'fractal_dimension_mean', 'concavity_se'), ('smoothness_mean', 'fractal_dimension_mean', 'concave points_se'), ('smoothness_mean', 'fractal_dimension_mean', 'symmetry_se'), ('smoothness_mean', 'fractal_dimension_mean', 'fractal_dimension_se'), ('smoothness_mean', 'fractal_dimension_mean', 'radius_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'texture_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'perimeter_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'area_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'compactness_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'concavity_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'concave points_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'symmetry_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'fractal_dimension_worst'), ('radius_mean', 'smoothness_mean', 'fractal_dimension_mean', 'smoothness_se'), ('texture_mean', 'smoothness_mean', 'fractal_dimension_mean', 'smoothness_se'), ('perimeter_mean', 'smoothness_mean', 'fractal_dimension_mean', 'smoothness_se'), ('area_mean', 'smoothness_mean', 'fractal_dimension_mean', 'smoothness_se'), ('smoothness_mean', 'compactness_mean', 'fractal_dimension_mean', 'smoothness_se'), ('smoothness_mean', 'concavity_mean', 'fractal_dimension_mean', 'smoothness_se'), ('smoothness_mean', 'concave points_mean', 'fractal_dimension_mean', 'smoothness_se'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), ('smoothness_mean', 'fractal_dimension_mean', 'radius_se', 'smoothness_se'), ('smoothness_mean', 'fractal_dimension_mean', 'texture_se', 'smoothness_se'), ('smo ...
#
# {'attributes': ('radius_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.41282554065365107}
# {'attributes': ('texture_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.4239571943782107}
# {'attributes': ('perimeter_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.41198796570705964}
# {'attributes': ('area_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.4097206113735271}
# {'attributes': ('smoothness_mean', 'compactness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.41372437784145183}
# {'attributes': ('smoothness_mean', 'concavity_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.4045858249140287}
# {'attributes': ('smoothness_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.4025659315451901}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'smoothness_se'), 'value': 0.4135300863374372}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'smoothness_se'), 'value': 0.4289595443786706}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'perimeter_se', 'smoothness_se'), 'value': 0.41394205687940344}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'area_se', 'smoothness_se'), 'value': 0.41330620583946287}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'compactness_se'), 'value': 0.42039060287630237}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'concavity_se'), 'value': 0.4194823328264835}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'concave points_se'), 'value': 0.4212877632912389}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'symmetry_se'), 'value': 0.4283406805569908}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'fractal_dimension_se'), 'value': 0.42284391006141064}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'radius_worst'), 'value': 0.40843811110299055}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'texture_worst'), 'value': 0.4232041284894851}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'perimeter_worst'), 'value': 0.4082283149546265}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'area_worst'), 'value': 0.4079835537265602}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'smoothness_worst'), 'value': 0.4274330886921236}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'compactness_worst'), 'value': 0.41290621959770635}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'concavity_worst'), 'value': 0.40895692272395345}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'concave points_worst'), 'value': 0.4045504724675997}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'symmetry_worst'), 'value': 0.4227246648442109}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'fractal_dimension_worst'), 'value': 0.42136412366297477}
# ========================================== find best value ===================================
# [{'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'smoothness_se'), 'value': 0.4289595443786706}]
# =============================================================================================
#
# ========================================== Subset_Score Round 6 =============================
#
# combination of previous round:===========> [('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), ('smoothness_mean', 'symmetry_mean', 'texture_se', 'smoothness_se'), ('smoothness_mean', 'fractal_dimension_mean', 'texture_se', 'smoothness_se'), ('symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'smoothness_se')]
# never occured combination:===============> [('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se'), ('smoothness_mean', 'symmetry_mean', 'texture_se', 'smoothness_se'), ('symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'smoothness_se')]
# ------------------------------------------calculate sbs check------------------------------------------
# {'attributes': ('radius_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se'), 'value': 0.4121176259150404}
# {'attributes': ('texture_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se'), 'value': 0.42324927963960013}
# {'attributes': ('perimeter_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se'), 'value': 0.4112800509684491}
# {'attributes': ('area_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se'), 'value': 0.4090126966349166}
# {'attributes': ('smoothness_mean', 'compactness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se'), 'value': 0.41301646310284124}
# {'attributes': ('smoothness_mean', 'concavity_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se'), 'value': 0.4038779101754182}
# {'attributes': ('smoothness_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se'), 'value': 0.4018580168065796}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se'), 'value': 0.41282217159882667}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'perimeter_se'), 'value': 0.41323414214079285}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'area_se'), 'value': 0.41259829110085233}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'compactness_se'), 'value': 0.4196826881376918}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'concavity_se'), 'value': 0.418774418087873}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'concave points_se'), 'value': 0.42057984855262837}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'symmetry_se'), 'value': 0.4276327658183803}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'fractal_dimension_se'), 'value': 0.4221359953228001}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'radius_worst'), 'value': 0.40773019636437996}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'texture_worst'), 'value': 0.4224962137508744}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'perimeter_worst'), 'value': 0.40752040021601593}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'area_worst'), 'value': 0.40727563898794966}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'smoothness_worst'), 'value': 0.42672517395351306}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'compactness_worst'), 'value': 0.4121983048590958}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'concavity_worst'), 'value': 0.40824900798534286}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'concave points_worst'), 'value': 0.4038425577289891}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'symmetry_worst'), 'value': 0.4220167501056003}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'fractal_dimension_worst'), 'value': 0.4206562089243643}
# {'attributes': ('radius_mean', 'smoothness_mean', 'symmetry_mean', 'texture_se', 'smoothness_se'), 'value': 0.40852116935243143}
# {'attributes': ('texture_mean', 'smoothness_mean', 'symmetry_mean', 'texture_se', 'smoothness_se'), 'value': 0.41965282307699114}
# {'attributes': ('perimeter_mean', 'smoothness_mean', 'symmetry_mean', 'texture_se', 'smoothness_se'), 'value': 0.4076835944058401}
# {'attributes': ('area_mean', 'smoothness_mean', 'symmetry_mean', 'texture_se', 'smoothness_se'), 'value': 0.4054162400723076}
# {'attributes': ('smoothness_mean', 'compactness_mean', 'symmetry_mean', 'texture_se', 'smoothness_se'), 'value': 0.40942000654023225}
# {'attributes': ('smoothness_mean', 'concavity_mean', 'symmetry_mean', 'texture_se', 'smoothness_se'), 'value': 0.4002814536128092}
# {'attributes': ('smoothness_mean', 'concave points_mean', 'symmetry_mean', 'texture_se', 'smoothness_se'), 'value': 0.3982615602439706}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'radius_se', 'texture_se', 'smoothness_se'), 'value': 0.4092257150362177}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'texture_se', 'perimeter_se', 'smoothness_se'), 'value': 0.40963768557818386}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'texture_se', 'area_se', 'smoothness_se'), 'value': 0.40900183453824335}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'texture_se', 'smoothness_se', 'compactness_se'), 'value': 0.4160862315750828}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'texture_se', 'smoothness_se', 'concavity_se'), 'value': 0.41517796152526404}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'texture_se', 'smoothness_se', 'concave points_se'), 'value': 0.4169833919900194}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'texture_se', 'smoothness_se', 'symmetry_se'), 'value': 0.4240363092557713}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'texture_se', 'smoothness_se', 'fractal_dimension_se'), 'value': 0.4185395387601911}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'texture_se', 'smoothness_se', 'radius_worst'), 'value': 0.404133739801771}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'texture_se', 'smoothness_se', 'texture_worst'), 'value': 0.41889975718826544}
# ...
#
# {'attributes': ('radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst'), 'value': 0.36538154796144257}
# ========================================== find best value ===================================
# [{'attributes': ('radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst'), 'value': 0.36538154796144257}]
# =============================================================================================
#
#
# best_subset_per_round :
#  =============== SubsetRanking ===============
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# --- 15556.541245698929 seconds ---
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# [{'attributes': ('fractal_dimension_mean',), 'value': 0.44332939000863186},
#  {'attributes': ('smoothness_mean', 'fractal_dimension_mean'),
#   'value': 0.43626673063507315},
#  {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se'),
#   'value': 0.43262685615524443},
#  {'attributes': ('smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'smoothness_se'),
#   'value': 0.43074754709770474},
#  {'attributes': ('smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se'),
#   'value': 0.4289595443786706},
#  {'attributes': ('smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'symmetry_se'),
#   'value': 0.4272518227145814},
#  {'attributes': ('smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'symmetry_se',
#    'smoothness_worst'),
#   'value': 0.42538374162246967},
#  {'attributes': ('texture_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'symmetry_se',
#    'smoothness_worst'),
#   'value': 0.4218102468571902},
#  {'attributes': ('texture_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'symmetry_se',
#    'texture_worst',
#    'smoothness_worst'),
#   'value': 0.4186124921015698},
#  {'attributes': ('texture_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'texture_worst',
#    'smoothness_worst'),
#   'value': 0.4158741790830362},
#  {'attributes': ('texture_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst'),
#   'value': 0.41357953878732706},
#  {'attributes': ('texture_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.4111004463820544},
#  {'attributes': ('texture_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.4089733834346176},
#  {'attributes': ('texture_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.40682977218862293},
#  {'attributes': ('texture_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.40466921909215464},
#  {'attributes': ('texture_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'perimeter_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.40104739889928237},
#  {'attributes': ('texture_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'perimeter_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.39778765195323285},
#  {'attributes': ('texture_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'radius_se',
#    'texture_se',
#    'perimeter_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.3948361292500736},
#  {'attributes': ('texture_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'radius_se',
#    'texture_se',
#    'perimeter_se',
#    'area_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.3921363772267274},
#  {'attributes': ('texture_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'radius_se',
#    'texture_se',
#    'perimeter_se',
#    'area_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'texture_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.3896066038452767},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'radius_se',
#    'texture_se',
#    'perimeter_se',
#    'area_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'texture_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.38729855198966523},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'radius_se',
#    'texture_se',
#    'perimeter_se',
#    'area_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'texture_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.38500996508761126},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'radius_se',
#    'texture_se',
#    'perimeter_se',
#    'area_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'texture_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.3824274826262723},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'radius_se',
#    'texture_se',
#    'perimeter_se',
#    'area_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'texture_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concavity_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.3799011052347172},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'radius_se',
#    'texture_se',
#    'perimeter_se',
#    'area_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concavity_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.37747307571029387},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'radius_se',
#    'texture_se',
#    'perimeter_se',
#    'area_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concavity_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.37519147227460237},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'radius_se',
#    'texture_se',
#    'perimeter_se',
#    'area_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'area_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concavity_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.3730335503474682},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'concavity_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'radius_se',
#    'texture_se',
#    'perimeter_se',
#    'area_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'area_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concavity_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.3704230284128917},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'concavity_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'radius_se',
#    'texture_se',
#    'perimeter_se',
#    'area_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'area_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concavity_worst',
#    'concave points_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.36798644722441887},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'concavity_mean',
#    'concave points_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'radius_se',
#    'texture_se',
#    'perimeter_se',
#    'area_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'area_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concavity_worst',
#    'concave points_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.36538154796144257}]

# %% [markdown]
# <h2> The Best Candidate Subset by SFFS

# %%
find_best_subset(best_subset_per_round)
# Out:
# ========================================== find best value ===================================
# [{'attributes': ('fractal_dimension_mean',), 'value': 0.44332939000863186}]
# =============================================================================================
# [{'attributes': ('fractal_dimension_mean',), 'value': 0.44332939000863186}]
