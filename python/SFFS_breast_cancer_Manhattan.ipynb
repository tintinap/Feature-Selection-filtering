# %%
#library
import pandas as pd
import numpy as np
import itertools
import seaborn as sns
import math

# %% [markdown]
# <H1>Dataset : Breast Cancer

# %%
df = pd.read_csv("../dataset/breast_cancer.csv")
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          17.33           184.60      2019.0           0.16220
# 1    ...          23.41           158.80      1956.0           0.12380
# 2    ...          25.53           152.50      1709.0           0.14440
# 3    ...          26.50            98.87       567.7           0.20980
# 4    ...          16.67           152.20      1575.0           0.13740
# ..   ...            ...              ...         ...               ...
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.11890          NaN
# 1                    0.08902          NaN
# 2                    0.08758          NaN
# 3                    0.17300          NaN
# 4                    0.07678          NaN
# ..                       ...          ...
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
#turn M = 1 B = 0
df["diagnosis"] = df['diagnosis'].apply(lambda i : 1 if i == 'M' else 0)
df
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# 1       1326.0          0.08474           0.07864         0.08690
# 2       1203.0          0.10960           0.15990         0.19740
# 3        386.1          0.14250           0.28390         0.24140
# 4       1297.0          0.10030           0.13280         0.19800
# ..         ...              ...               ...             ...
# 564     1479.0          0.11100           0.11590         0.24390
# 565     1261.0          0.09780           0.10340         0.14400
# 566      858.1          0.08455           0.10230         0.09251
# 567     1265.0          0.11780           0.27700         0.35140
# 568      181.0          0.05263           0.04362         0.00000
#
#      concave points_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0                0.14710  ...          17.33           184.60      2019.0
# 1                0.07017  ...          23.41           158.80      1956.0
# 2                0.12790  ...          25.53           152.50      1709.0
# 3                0.10520  ...          26.50            98.87       567.7
# 4                0.10430  ...          16.67           152.20      1575.0
# ..                   ...  ...            ...              ...         ...
# 564              0.13890  ...          26.40           166.10      2027.0
# 565              0.09791  ...          38.25           155.00      1731.0
# 566              0.05302  ...          34.12           126.70      1124.0
# 567              0.15200  ...          39.42           184.60      1821.0
# 568              0.00000  ...          30.37            59.16       268.6
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst  \
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
#      Unnamed: 32
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 564          NaN
# 565          NaN
# 566          NaN
# 567          NaN
# 568          NaN
#
# [569 rows x 33 columns]

# %% [markdown]
# <h1>Features

# %%
features = df.columns.tolist()[2:-1]
features
# Out:
# ['radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'radius_se',
#  'texture_se',
#  'perimeter_se',
#  'area_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave points_se',
#  'symmetry_se',
#  'fractal_dimension_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst',
#  'concave points_worst',
#  'symmetry_worst',
#  'fractal_dimension_worst']

# %%
X = df[features]
X
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 0                   0.07871  ...        25.380          17.33
# 1                   0.05667  ...        24.990          23.41
# 2                   0.05999  ...        23.570          25.53
# 3                   0.09744  ...        14.910          26.50
# 4                   0.05883  ...        22.540          16.67
# ..                      ...  ...           ...            ...
# 564                 0.05623  ...        25.450          26.40
# 565                 0.05533  ...        23.690          38.25
# 566                 0.05648  ...        18.980          34.12
# 567                 0.07016  ...        25.740          39.42
# 568                 0.05884  ...         9.456          30.37
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0             184.60      2019.0           0.16220            0.66560
# 1             158.80      1956.0           0.12380            0.18660
# 2             152.50      1709.0           0.14440            0.42450
# 3              98.87       567.7           0.20980            0.86630
# 4             152.20      1575.0           0.13740            0.20500
# ..               ...         ...               ...                ...
# 564           166.10      2027.0           0.14100            0.21130
# 565           155.00      1731.0           0.11660            0.19220
# 566           126.70      1124.0           0.11390            0.30940
# 567           184.60      1821.0           0.16500            0.86810
# 568            59.16       268.6           0.08996            0.06444
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.7119                0.2654          0.4601
# 1             0.2416                0.1860          0.2750
# 2             0.4504                0.2430          0.3613
# 3             0.6869                0.2575          0.6638
# 4             0.4000                0.1625          0.2364
# ..               ...                   ...             ...
# 564           0.4107                0.2216          0.2060
# 565           0.3215                0.1628          0.2572
# 566           0.3403                0.1418          0.2218
# 567           0.9387                0.2650          0.4087
# 568           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 564                  0.07115
# 565                  0.06637
# 566                  0.07820
# 567                  0.12400
# 568                  0.07039
#
# [569 rows x 30 columns]

# %% [markdown]
# <h2> Normalization Data

# %%
X = df[features].apply(lambda x: (x - x.min()) / (x.max() - x.min()))
X
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       0.521037      0.022658        0.545989   0.363733         0.593753
# 1       0.643144      0.272574        0.615783   0.501591         0.289880
# 2       0.601496      0.390260        0.595743   0.449417         0.514309
# 3       0.210090      0.360839        0.233501   0.102906         0.811321
# 4       0.629893      0.156578        0.630986   0.489290         0.430351
# ..           ...           ...             ...        ...              ...
# 564     0.690000      0.428813        0.678668   0.566490         0.526948
# 565     0.622320      0.626987        0.604036   0.474019         0.407782
# 566     0.455251      0.621238        0.445788   0.303118         0.288165
# 567     0.644564      0.663510        0.665538   0.475716         0.588336
# 568     0.036869      0.501522        0.028540   0.015907         0.000000
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0            0.792037        0.703140             0.731113       0.686364
# 1            0.181768        0.203608             0.348757       0.379798
# 2            0.431017        0.462512             0.635686       0.509596
# 3            0.811361        0.565604             0.522863       0.776263
# 4            0.347893        0.463918             0.518390       0.378283
# ..                ...             ...                  ...            ...
# 564          0.296055        0.571462             0.690358       0.336364
# 565          0.257714        0.337395             0.486630       0.349495
# 566          0.254340        0.216753             0.263519       0.267677
# 567          0.790197        0.823336             0.755467       0.675253
# 568          0.074351        0.000000             0.000000       0.266162
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 0                  0.605518  ...      0.620776       0.141525
# 1                  0.141323  ...      0.606901       0.303571
# 2                  0.211247  ...      0.556386       0.360075
# 3                  1.000000  ...      0.248310       0.385928
# 4                  0.186816  ...      0.519744       0.123934
# ..                      ...  ...           ...            ...
# 564                0.132056  ...      0.623266       0.383262
# 565                0.113100  ...      0.560655       0.699094
# 566                0.137321  ...      0.393099       0.589019
# 567                0.425442  ...      0.633582       0.730277
# 568                0.187026  ...      0.054287       0.489072
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0           0.668310    0.450698          0.601136           0.619292
# 1           0.539818    0.435214          0.347553           0.154563
# 2           0.508442    0.374508          0.483590           0.385375
# 3           0.241347    0.094008          0.915472           0.814012
# 4           0.506948    0.341575          0.437364           0.172415
# ..               ...         ...               ...                ...
# 564         0.576174    0.452664          0.461137           0.178527
# 565         0.520892    0.379915          0.300007           0.159997
# 566         0.379949    0.230731          0.282177           0.273705
# 567         0.668310    0.402035          0.619626           0.815758
# 568         0.043578    0.020497          0.124084           0.036043
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 0           0.568610              0.912027        0.598462
# 1           0.192971              0.639175        0.233590
# 2           0.359744              0.835052        0.403706
# 3           0.548642              0.884880        1.000000
# 4           0.319489              0.558419        0.157500
# ..               ...                   ...             ...
# 564         0.328035              0.761512        0.097575
# 565         0.256789              0.559450        0.198502
# 566         0.271805              0.487285        0.128721
# 567         0.749760              0.910653        0.497142
# 568         0.000000              0.000000        0.257441
#
#      fractal_dimension_worst
# 0                   0.418864
# 1                   0.222878
# 2                   0.213433
# 3                   0.773711
# 4                   0.142595
# ..                       ...
# 564                 0.105667
# 565                 0.074315
# 566                 0.151909
# 567                 0.452315
# 568                 0.100682
#
# [569 rows x 30 columns]

# %%
label = 'diagnosis'
label
# Out:
# 'diagnosis'

# %%
y = df['diagnosis']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int64

# %%
num_feats = X.shape[1]
num_feats
# Out:
# 30

# %% [markdown]
# <h2> Manhattan Distance Table

# %%
df_md = {label: []}

for f in features:
    df_md[label].append(np.mean([math.sqrt(abs(a[0]-a[1])) for a in zip(X[f], y)]))

df_md = pd.DataFrame.from_dict(df_md)
df_md.index = features
df_md
# Out:
#                          diagnosis
# radius_mean               0.565046
# texture_mean              0.606370
# perimeter_mean            0.560594
# area_mean                 0.520975
# smoothness_mean           0.644291
# compactness_mean          0.548821
# concavity_mean            0.476544
# concave points_mean       0.485908
# symmetry_mean             0.637731
# fractal_dimension_mean    0.633403
# radius_se                 0.484189
# texture_se                0.592743
# perimeter_se              0.482811
# area_se                   0.445147
# smoothness_se             0.599121
# compactness_se            0.547306
# concavity_se              0.495511
# concave points_se         0.572493
# symmetry_se               0.591852
# fractal_dimension_se      0.528070
# radius_worst              0.538328
# texture_worst             0.606959
# perimeter_worst           0.534587
# area_worst                0.493213
# smoothness_worst          0.630133
# compactness_worst         0.532630
# concavity_worst           0.504351
# concave points_worst      0.524477
# symmetry_worst            0.593832
# fractal_dimension_worst   0.564372

# %% [markdown]
# <h1>Function

# %%
def grouping_attribute_score(attrubutes, value):
    '''combine value to dictionary format'''
    return {"attributes": attrubutes, "value": value}

# %%
def find_best_subset(subset_score, max_min='max'):
    """find best score of subset subset score is list of grouping_attribute_score
        max_min (str) : can be only 'max' or 'min' to define the best value
    """
    #still available for only a group of attributes
    print('========================================== find best value ===================================')
    best_subset_score = []
    
    if max_min == 'min':
        # min is the best
        subset_score.sort(key=lambda x: x['value'], reverse=False)
    else:        
        #max is the best
        subset_score.sort(key=lambda x: x['value'], reverse=True)

    best_subset_score.append(subset_score[0])
    print(best_subset_score)
    print("=============================================================================================")
    return best_subset_score
# return [{'attrubute': ('Glucose', 'BMI'), 'value': 0.3796380304756596}]

# %%
def cal_best(algo_round, max_min='max'):
    """match all subset and find the best one
        max_min (str) : can be only 'max' or 'min' to define the best value
    """
    #start calculating
    subset_score = []
    subset_mean = []
    
    #use mean of all manhattan distance of subset
    for atrs in algo_round:
        temp_score_mean = []
        for i in atrs:
            #manhattan distance
            md = df_md[label][i]
            temp_score_mean.append(md)
        subset_mean.append(np.mean(temp_score_mean)) #score
        
    for atrs,mean_score in zip(algo_round,subset_mean):
        subset_score.append(grouping_attribute_score(atrs, mean_score))
    [print(i) for i in subset_score]
    return find_best_subset(subset_score=subset_score, max_min=max_min)

# %% [markdown]
# <h1>SFFS

# %%
best_subset_per_round = []
combination_history = []
for num in range(1, num_feats+1):   
    print("========================================== Subset_Score Round", num,'=============================')
    if num == 1: #1st round
        #combination of subset in each round
        sfs_round = list(itertools.combinations(features, num))

        print()        
        best_subset_per_round.append(cal_best(algo_round=sfs_round, max_min='max'))
        print()
        
    elif num == 2 or num == 3:
        #combination of subset in each round
        sfs_round = list(itertools.combinations(features, num))
        
        #hv to pop non-best_subset out
        sfs_round_temp = []
        for i in range(len(sfs_round)):
            if all(attr in sfs_round[i] for attr in best_subset_per_round[num-2][0]['attributes']):
                sfs_round_temp.append(sfs_round[i])
        sfs_round = sfs_round_temp
        #record the history of combination
        combination_history.extend(sfs_round)
        print('combination_hist:=====================>', combination_history)
        
        print()
        best_subset_per_round.append(cal_best(algo_round=sfs_round, max_min='max'))
        print()
        
    else: #other round
        print()
        #combination
        sfs_check = list(itertools.combinations(best_subset_per_round[-1][0]['attributes'], num-2))
        print('combination of previous round:===========>', sfs_check)
        #check history
        [sfs_check.remove(i) for i in sfs_check if i in combination_history]
                
        print('never occured combination:===============>', sfs_check)
        #combination in the same number as last round that has sfs_check inside
        check_temp = []
        comb_temp = list(itertools.combinations(features, num-1))
        for j in range(len(sfs_check)):
            for i in range(len(comb_temp)):
                if all(attr in comb_temp[i] for attr in sfs_check[j]):
                    check_temp.append(comb_temp[i])
        comb_temp = check_temp
        #check history
        [comb_temp.remove(i) for i in comb_temp if i in combination_history]
        print()
        print('------------------------------------------calculate sbs check------------------------------------------')
        sbs_check = cal_best(comb_temp)
        print('sbs check:',sbs_check)
        print('current best', best_subset_per_round[-1])
        if sbs_check[0]['value'] > best_subset_per_round[-1][0]['value']: #max is the best
            print('privoue best_subset_score ----->', best_subset_per_round)
            print('new value')
            best_subset_per_round[-1][0] = sbs_check[0]
        print('current best_subset_score ----->', best_subset_per_round)
        print('------------------------------------------calculate sbs check------------------------------------------')
        print()
        sfs_round = list(itertools.combinations(features, num))
        
        #hv to pop non-best_subset out
        sfs_round_temp = []
        for i in range(len(sfs_round)):
            if all(attr in sfs_round[i] for attr in best_subset_per_round[num-2][0]['attributes']):
                sfs_round_temp.append(sfs_round[i])
        sfs_round = sfs_round_temp
        #record the history of combination
        combination_history.extend(sfs_round)
        print('combination_hist:=====================>', combination_history)
        
        print()
        best_subset_per_round.append(cal_best(algo_round=sfs_round, max_min='max'))
        print()       
        
print()
print('best_subset_per_round :',"\n", '=============== SubsetRanking ===============')
# [print(i) for i in best_subset_per_round]

best_temp = [i[0] for i in best_subset_per_round]
best_subset_per_round = best_temp
best_subset_per_round.sort(key=lambda x: x['value'], reverse=True) # max is the best
best_subset_per_round
# Out:
# ========================================== Subset_Score Round 1 =============================
#
# {'attributes': ('radius_mean',), 'value': 0.5650459649409828}
# {'attributes': ('texture_mean',), 'value': 0.6063702885160982}
# {'attributes': ('perimeter_mean',), 'value': 0.5605943525552071}
# {'attributes': ('area_mean',), 'value': 0.5209752918080648}
# {'attributes': ('smoothness_mean',), 'value': 0.644291062764079}
# {'attributes': ('compactness_mean',), 'value': 0.5488209720120854}
# {'attributes': ('concavity_mean',), 'value': 0.4765443964681796}
# {'attributes': ('concave points_mean',), 'value': 0.4859079746206317}
# {'attributes': ('symmetry_mean',), 'value': 0.6377309835790883}
# {'attributes': ('fractal_dimension_mean',), 'value': 0.6334032182114963}
# {'attributes': ('radius_se',), 'value': 0.48418860803147584}
# {'attributes': ('texture_se',), 'value': 0.592743185063127}
# {'attributes': ('perimeter_se',), 'value': 0.4828108780960401}
# {'attributes': ('area_se',), 'value': 0.4451470323803762}
# {'attributes': ('smoothness_se',), 'value': 0.5991210716105903}
# {'attributes': ('compactness_se',), 'value': 0.5473058895423677}
# {'attributes': ('concavity_se',), 'value': 0.4955113138932414}
# {'attributes': ('concave points_se',), 'value': 0.5724925352412706}
# {'attributes': ('symmetry_se',), 'value': 0.5918515451261019}
# {'attributes': ('fractal_dimension_se',), 'value': 0.5280698583550337}
# {'attributes': ('radius_worst',), 'value': 0.5383277031274561}
# {'attributes': ('texture_worst',), 'value': 0.6069593830231431}
# {'attributes': ('perimeter_worst',), 'value': 0.5345871284950781}
# {'attributes': ('area_worst',), 'value': 0.4932133928496861}
# {'attributes': ('smoothness_worst',), 'value': 0.6301325901858154}
# {'attributes': ('compactness_worst',), 'value': 0.5326304640516255}
# {'attributes': ('concavity_worst',), 'value': 0.5043507285950775}
# {'attributes': ('concave points_worst',), 'value': 0.5244766869533953}
# {'attributes': ('symmetry_worst',), 'value': 0.593832330906787}
# {'attributes': ('fractal_dimension_worst',), 'value': 0.5643721415618781}
# ========================================== find best value ===================================
# [{'attributes': ('smoothness_mean',), 'value': 0.644291062764079}]
# =============================================================================================
#
# ========================================== Subset_Score Round 2 =============================
# combination_hist:=====================> [('radius_mean', 'smoothness_mean'), ('texture_mean', 'smoothness_mean'), ('perimeter_mean', 'smoothness_mean'), ('area_mean', 'smoothness_mean'), ('smoothness_mean', 'compactness_mean'), ('smoothness_mean', 'concavity_mean'), ('smoothness_mean', 'concave points_mean'), ('smoothness_mean', 'symmetry_mean'), ('smoothness_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'radius_se'), ('smoothness_mean', 'texture_se'), ('smoothness_mean', 'perimeter_se'), ('smoothness_mean', 'area_se'), ('smoothness_mean', 'smoothness_se'), ('smoothness_mean', 'compactness_se'), ('smoothness_mean', 'concavity_se'), ('smoothness_mean', 'concave points_se'), ('smoothness_mean', 'symmetry_se'), ('smoothness_mean', 'fractal_dimension_se'), ('smoothness_mean', 'radius_worst'), ('smoothness_mean', 'texture_worst'), ('smoothness_mean', 'perimeter_worst'), ('smoothness_mean', 'area_worst'), ('smoothness_mean', 'smoothness_worst'), ('smoothness_mean', 'compactness_worst'), ('smoothness_mean', 'concavity_worst'), ('smoothness_mean', 'concave points_worst'), ('smoothness_mean', 'symmetry_worst'), ('smoothness_mean', 'fractal_dimension_worst')]
#
# {'attributes': ('radius_mean', 'smoothness_mean'), 'value': 0.604668513852531}
# {'attributes': ('texture_mean', 'smoothness_mean'), 'value': 0.6253306756400886}
# {'attributes': ('perimeter_mean', 'smoothness_mean'), 'value': 0.602442707659643}
# {'attributes': ('area_mean', 'smoothness_mean'), 'value': 0.5826331772860719}
# {'attributes': ('smoothness_mean', 'compactness_mean'), 'value': 0.5965560173880822}
# {'attributes': ('smoothness_mean', 'concavity_mean'), 'value': 0.5604177296161292}
# {'attributes': ('smoothness_mean', 'concave points_mean'), 'value': 0.5650995186923553}
# {'attributes': ('smoothness_mean', 'symmetry_mean'), 'value': 0.6410110231715836}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean'), 'value': 0.6388471404877876}
# {'attributes': ('smoothness_mean', 'radius_se'), 'value': 0.5642398353977774}
# {'attributes': ('smoothness_mean', 'texture_se'), 'value': 0.6185171239136029}
# {'attributes': ('smoothness_mean', 'perimeter_se'), 'value': 0.5635509704300595}
# {'attributes': ('smoothness_mean', 'area_se'), 'value': 0.5447190475722276}
# {'attributes': ('smoothness_mean', 'smoothness_se'), 'value': 0.6217060671873347}
# {'attributes': ('smoothness_mean', 'compactness_se'), 'value': 0.5957984761532233}
# {'attributes': ('smoothness_mean', 'concavity_se'), 'value': 0.5699011883286602}
# {'attributes': ('smoothness_mean', 'concave points_se'), 'value': 0.6083917990026748}
# {'attributes': ('smoothness_mean', 'symmetry_se'), 'value': 0.6180713039450905}
# {'attributes': ('smoothness_mean', 'fractal_dimension_se'), 'value': 0.5861804605595564}
# {'attributes': ('smoothness_mean', 'radius_worst'), 'value': 0.5913093829457676}
# {'attributes': ('smoothness_mean', 'texture_worst'), 'value': 0.625625222893611}
# {'attributes': ('smoothness_mean', 'perimeter_worst'), 'value': 0.5894390956295785}
# {'attributes': ('smoothness_mean', 'area_worst'), 'value': 0.5687522278068826}
# {'attributes': ('smoothness_mean', 'smoothness_worst'), 'value': 0.6372118264749471}
# {'attributes': ('smoothness_mean', 'compactness_worst'), 'value': 0.5884607634078522}
# {'attributes': ('smoothness_mean', 'concavity_worst'), 'value': 0.5743208956795782}
# {'attributes': ('smoothness_mean', 'concave points_worst'), 'value': 0.5843838748587371}
# {'attributes': ('smoothness_mean', 'symmetry_worst'), 'value': 0.619061696835433}
# {'attributes': ('smoothness_mean', 'fractal_dimension_worst'), 'value': 0.6043316021629785}
# ========================================== find best value ===================================
# [{'attributes': ('smoothness_mean', 'symmetry_mean'), 'value': 0.6410110231715836}]
# =============================================================================================
#
# ========================================== Subset_Score Round 3 =============================
# combination_hist:=====================> [('radius_mean', 'smoothness_mean'), ('texture_mean', 'smoothness_mean'), ('perimeter_mean', 'smoothness_mean'), ('area_mean', 'smoothness_mean'), ('smoothness_mean', 'compactness_mean'), ('smoothness_mean', 'concavity_mean'), ('smoothness_mean', 'concave points_mean'), ('smoothness_mean', 'symmetry_mean'), ('smoothness_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'radius_se'), ('smoothness_mean', 'texture_se'), ('smoothness_mean', 'perimeter_se'), ('smoothness_mean', 'area_se'), ('smoothness_mean', 'smoothness_se'), ('smoothness_mean', 'compactness_se'), ('smoothness_mean', 'concavity_se'), ('smoothness_mean', 'concave points_se'), ('smoothness_mean', 'symmetry_se'), ('smoothness_mean', 'fractal_dimension_se'), ('smoothness_mean', 'radius_worst'), ('smoothness_mean', 'texture_worst'), ('smoothness_mean', 'perimeter_worst'), ('smoothness_mean', 'area_worst'), ('smoothness_mean', 'smoothness_worst'), ('smoothness_mean', 'compactness_worst'), ('smoothness_mean', 'concavity_worst'), ('smoothness_mean', 'concave points_worst'), ('smoothness_mean', 'symmetry_worst'), ('smoothness_mean', 'fractal_dimension_worst'), ('radius_mean', 'smoothness_mean', 'symmetry_mean'), ('texture_mean', 'smoothness_mean', 'symmetry_mean'), ('perimeter_mean', 'smoothness_mean', 'symmetry_mean'), ('area_mean', 'smoothness_mean', 'symmetry_mean'), ('smoothness_mean', 'compactness_mean', 'symmetry_mean'), ('smoothness_mean', 'concavity_mean', 'symmetry_mean'), ('smoothness_mean', 'concave points_mean', 'symmetry_mean'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'symmetry_mean', 'radius_se'), ('smoothness_mean', 'symmetry_mean', 'texture_se'), ('smoothness_mean', 'symmetry_mean', 'perimeter_se'), ('smoothness_mean', 'symmetry_mean', 'area_se'), ('smoothness_mean', 'symmetry_mean', 'smoothness_se'), ('smoothness_mean', 'symmetry_mean', 'compactness_se'), ('smoothness_mean', 'symmetry_mean', 'concavity_se'), ('smoothness_mean', 'symmetry_mean', 'concave points_se'), ('smoothness_mean', 'symmetry_mean', 'symmetry_se'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_se'), ('smoothness_mean', 'symmetry_mean', 'radius_worst'), ('smoothness_mean', 'symmetry_mean', 'texture_worst'), ('smoothness_mean', 'symmetry_mean', 'perimeter_worst'), ('smoothness_mean', 'symmetry_mean', 'area_worst'), ('smoothness_mean', 'symmetry_mean', 'smoothness_worst'), ('smoothness_mean', 'symmetry_mean', 'compactness_worst'), ('smoothness_mean', 'symmetry_mean', 'concavity_worst'), ('smoothness_mean', 'symmetry_mean', 'concave points_worst'), ('smoothness_mean', 'symmetry_mean', 'symmetry_worst'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_worst')]
#
# {'attributes': ('radius_mean', 'smoothness_mean', 'symmetry_mean'), 'value': 0.6156893370947167}
# {'attributes': ('texture_mean', 'smoothness_mean', 'symmetry_mean'), 'value': 0.6294641116197551}
# {'attributes': ('perimeter_mean', 'smoothness_mean', 'symmetry_mean'), 'value': 0.6142054662994582}
# {'attributes': ('area_mean', 'smoothness_mean', 'symmetry_mean'), 'value': 0.6009991127170774}
# {'attributes': ('smoothness_mean', 'compactness_mean', 'symmetry_mean'), 'value': 0.6102810061184175}
# {'attributes': ('smoothness_mean', 'concavity_mean', 'symmetry_mean'), 'value': 0.5861888142704489}
# {'attributes': ('smoothness_mean', 'concave points_mean', 'symmetry_mean'), 'value': 0.589310006987933}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.6384750881848879}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'radius_se'), 'value': 0.5887368847915477}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'texture_se'), 'value': 0.6249217438020981}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'perimeter_se'), 'value': 0.5882776414797358}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'area_se'), 'value': 0.5757230262411811}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_se'), 'value': 0.6270477059845859}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'compactness_se'), 'value': 0.6097759786285116}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'concavity_se'), 'value': 0.5925111200788029}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'concave points_se'), 'value': 0.6181715271948126}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'symmetry_se'), 'value': 0.6246245304897564}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_se'), 'value': 0.6033639682327337}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'radius_worst'), 'value': 0.6067832498235411}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'texture_worst'), 'value': 0.6296604764554368}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'perimeter_worst'), 'value': 0.6055363916127484}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'area_worst'), 'value': 0.5917451463976179}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_worst'), 'value': 0.6373848788429942}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'compactness_worst'), 'value': 0.6048841701315976}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'concavity_worst'), 'value': 0.5954575916460816}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'concave points_worst'), 'value': 0.6021662444321875}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'symmetry_worst'), 'value': 0.6252847924166515}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_worst'), 'value': 0.6154647293016818}
# ========================================== find best value ===================================
# [{'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.6384750881848879}]
# =============================================================================================
#
# ========================================== Subset_Score Round 4 =============================
#
# combination of previous round:===========> [('smoothness_mean', 'symmetry_mean'), ('smoothness_mean', 'fractal_dimension_mean'), ('symmetry_mean', 'fractal_dimension_mean')]
# never occured combination:===============> [('smoothness_mean', 'fractal_dimension_mean'), ('symmetry_mean', 'fractal_dimension_mean')]
#
# ------------------------------------------calculate sbs check------------------------------------------
# {'attributes': ('radius_mean', 'smoothness_mean', 'fractal_dimension_mean'), 'value': 0.6142467486388528}
# {'attributes': ('texture_mean', 'smoothness_mean', 'fractal_dimension_mean'), 'value': 0.6280215231638911}
# {'attributes': ('perimeter_mean', 'smoothness_mean', 'fractal_dimension_mean'), 'value': 0.6127628778435942}
# {'attributes': ('area_mean', 'smoothness_mean', 'fractal_dimension_mean'), 'value': 0.5995565242612133}
# {'attributes': ('smoothness_mean', 'compactness_mean', 'fractal_dimension_mean'), 'value': 0.6088384176625535}
# {'attributes': ('smoothness_mean', 'concavity_mean', 'fractal_dimension_mean'), 'value': 0.5847462258145849}
# {'attributes': ('smoothness_mean', 'concave points_mean', 'fractal_dimension_mean'), 'value': 0.587867418532069}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'radius_se'), 'value': 0.5872942963356836}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'texture_se'), 'value': 0.6234791553462341}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'perimeter_se'), 'value': 0.5868350530238717}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'area_se'), 'value': 0.5742804377853171}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.6256051175287217}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'compactness_se'), 'value': 0.6083333901726476}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'concavity_se'), 'value': 0.5910685316229388}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'concave points_se'), 'value': 0.6167289387389486}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'symmetry_se'), 'value': 0.6231819420338923}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'fractal_dimension_se'), 'value': 0.6019213797768695}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'radius_worst'), 'value': 0.6053406613676771}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'texture_worst'), 'value': 0.6282178879995728}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'perimeter_worst'), 'value': 0.6040938031568844}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'area_worst'), 'value': 0.5903025579417537}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6359422903871302}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'compactness_worst'), 'value': 0.6034415816757336}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'concavity_worst'), 'value': 0.5940150031902175}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'concave points_worst'), 'value': 0.6007236559763235}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'symmetry_worst'), 'value': 0.6238422039607874}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'fractal_dimension_worst'), 'value': 0.6140221408458177}
# {'attributes': ('radius_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.6120600555771891}
# {'attributes': ('texture_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.6258348301022276}
# {'attributes': ('perimeter_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.6105761847819305}
# {'attributes': ('area_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.5973698311995498}
# {'attributes': ('compactness_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.6066517246008899}
# {'attributes': ('concavity_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.5825595327529215}
# {'attributes': ('concave points_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.5856807254704054}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'radius_se'), 'value': 0.5851076032740202}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'texture_se'), 'value': 0.6212924622845706}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'perimeter_se'), 'value': 0.5846483599622082}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'area_se'), 'value': 0.5720937447236536}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.6234184244670583}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'compactness_se'), 'value': 0.6061466971109841}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'concavity_se'), 'value': 0.5888818385612754}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'concave points_se'), 'value': 0.6145422456772851}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'symmetry_se'), 'value': 0.6209952489722289}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'fractal_dimension_se'), 'value': 0.5997346867152061}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'radius_worst'), 'value': 0.6031539683060135}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'texture_worst'), 'value': 0.6260311949379093}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'perimeter_worst'), 'value': 0.6019071100952209}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'area_worst'), 'value': 0.5881158648800903}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6337555973254667}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'compactness_worst'), 'value': 0.6012548886140701}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'concavity_worst'), 'value': 0.5918283101285541}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'concave points_worst'), 'value': 0.5985369629146601}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'symmetry_worst'), 'value': 0.6216555108991239}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'fractal_dimension_worst'), 'value': 0.6118354477841542}
# ========================================== find best value ===================================
# [{'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6359422903871302}]
# =============================================================================================
# sbs check: [{'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6359422903871302}]
# current best [{'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.6384750881848879}]
# current best_subset_score -----> [[{'attributes': ('smoothness_mean',), 'value': 0.644291062764079}], [{'attributes': ('smoothness_mean', 'symmetry_mean'), 'value': 0.6410110231715836}], [{'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.6384750881848879}]]
# ------------------------------------------calculate sbs check------------------------------------------
#
# combination_hist:=====================> [('radius_mean', 'smoothness_mean'), ('texture_mean', 'smoothness_mean'), ('perimeter_mean', 'smoothness_mean'), ('area_mean', 'smoothness_mean'), ('smoothness_mean', 'compactness_mean'), ('smoothness_mean', 'concavity_mean'), ('smoothness_mean', 'concave points_mean'), ('smoothness_mean', 'symmetry_mean'), ('smoothness_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'radius_se'), ('smoothness_mean', 'texture_se'), ('smoothness_mean', 'perimeter_se'), ('smoothness_mean', 'area_se'), ('smoothness_mean', 'smoothness_se'), ('smoothness_mean', 'compactness_se'), ('smoothness_mean', 'concavity_se'), ('smoothness_mean', 'concave points_se'), ('smoothness_mean', 'symmetry_se'), ('smoothness_mean', 'fractal_dimension_se'), ('smoothness_mean', 'radius_worst'), ('smoothness_mean', 'texture_worst'), ('smoothness_mean', 'perimeter_worst'), ('smoothness_mean', 'area_worst'), ('smoothness_mean', 'smoothness_worst'), ('smoothness_mean', 'compactness_worst'), ('smoothness_mean', 'concavity_worst'), ('smoothness_mean', 'concave points_worst'), ('smoothness_mean', 'symmetry_worst'), ('smoothness_mean', 'fractal_dimension_worst'), ('radius_mean', 'smoothness_mean', 'symmetry_mean'), ('texture_mean', 'smoothness_mean', 'symmetry_mean'), ('perimeter_mean', 'smoothness_mean', 'symmetry_mean'), ('area_mean', 'smoothness_mean', 'symmetry_mean'), ('smoothness_mean', 'compactness_mean', 'symmetry_mean'), ('smoothness_mean', 'concavity_mean', 'symmetry_mean'), ('smoothness_mean', 'concave points_mean', 'symmetry_mean'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'symmetry_mean', 'radius_se'), ('smoothness_mean', 'symmetry_mean', 'texture_se'), ('smoothness_mean', 'symmetry_mean', 'perimeter_se'), ('smoothness_mean', 'symmetry_mean', 'area_se'), ('smoothness_mean', 'symmetry_mean', 'smoothness_se'), ('smoothness_mean', 'symmetry_mean', 'compactness_se'), ('smoothness_mean', 'symmetry_mean', 'concavity_se'), ('smoothness_mean', 'symmetry_mean', 'concave points_se'), ('smoothness_mean', 'symmetry_mean', 'symmetry_se'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_se'), ('smoothness_mean', 'symmetry_mean', 'radius_worst'), ('smoothness_mean', 'symmetry_mean', 'texture_worst'), ('smoothness_mean', 'symmetry_mean', 'perimeter_worst'), ('smoothness_mean', 'symmetry_mean', 'area_worst'), ('smoothness_mean', 'symmetry_mean', 'smoothness_worst'), ('smoothness_mean', 'symmetry_mean', 'compactness_worst'), ('smoothness_mean', 'symmetry_mean', 'concavity_worst'), ('smoothness_mean', 'symmetry_mean', 'concave points_worst'), ('smoothness_mean', 'symmetry_mean', 'symmetry_worst'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_worst'), ('radius_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), ('texture_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), ('perimeter_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), ('area_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'compactness_mean', 'symmetry_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'concavity_mean', 'symmetry_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'perimeter_se'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'area_se'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'compactness_se'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'concavity_se'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'concave points_se'), ('smoothness_mean', 'symmetry_mean', 'frac ...
#
# {'attributes': ('radius_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.6201178073739116}
# {'attributes': ('texture_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.6304488882676904}
# {'attributes': ('perimeter_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.6190049042774677}
# {'attributes': ('area_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.6091001390906821}
# {'attributes': ('smoothness_mean', 'compactness_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.6160615591416873}
# {'attributes': ('smoothness_mean', 'concavity_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.5979924152557108}
# {'attributes': ('smoothness_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.6003333097938238}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se'), 'value': 0.5999034681465348}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se'), 'value': 0.6270421124044476}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'perimeter_se'), 'value': 0.5995590356626759}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'area_se'), 'value': 0.5901430742337599}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.6286365840413134}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'compactness_se'), 'value': 0.6156827885242577}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'concavity_se'), 'value': 0.6027341446119762}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'concave points_se'), 'value': 0.6219794499489835}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'symmetry_se'), 'value': 0.6268192024201913}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'fractal_dimension_se'), 'value': 0.6108737807274243}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_worst'), 'value': 0.6134382419205299}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_worst'), 'value': 0.6305961618944517}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'perimeter_worst'), 'value': 0.6125030982624353}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'area_worst'), 'value': 0.6021596643510874}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6363894636851197}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'compactness_worst'), 'value': 0.6120139321515723}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'concavity_worst'), 'value': 0.6049439982874352}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'concave points_worst'), 'value': 0.6099754878770147}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'symmetry_worst'), 'value': 0.6273143988653627}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'fractal_dimension_worst'), 'value': 0.6199493515291354}
# ========================================== find best value ===================================
# [{'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6363894636851197}]
# =============================================================================================
#
# ========================================== Subset_Score Round 5 =============================
#
# combination of previous round:===========> [('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'symmetry_mean', 'smoothness_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_worst'), ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst')]
# never occured combination:===============> [('smoothness_mean', 'symmetry_mean', 'smoothness_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_worst'), ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst')]
#
# ------------------------------------------calculate sbs check------------------------------------------
# {'attributes': ('radius_mean', 'smoothness_mean', 'symmetry_mean', 'smoothness_worst'), 'value': 0.6193001503674914}
# {'attributes': ('texture_mean', 'smoothness_mean', 'symmetry_mean', 'smoothness_worst'), 'value': 0.6296312312612702}
# {'attributes': ('perimeter_mean', 'smoothness_mean', 'symmetry_mean', 'smoothness_worst'), 'value': 0.6181872472710475}
# {'attributes': ('area_mean', 'smoothness_mean', 'symmetry_mean', 'smoothness_worst'), 'value': 0.6082824820842618}
# {'attributes': ('smoothness_mean', 'compactness_mean', 'symmetry_mean', 'smoothness_worst'), 'value': 0.615243902135267}
# {'attributes': ('smoothness_mean', 'concavity_mean', 'symmetry_mean', 'smoothness_worst'), 'value': 0.5971747582492906}
# {'attributes': ('smoothness_mean', 'concave points_mean', 'symmetry_mean', 'smoothness_worst'), 'value': 0.5995156527874036}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'radius_se', 'smoothness_worst'), 'value': 0.5990858111401146}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'texture_se', 'smoothness_worst'), 'value': 0.6262244553980274}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'perimeter_se', 'smoothness_worst'), 'value': 0.5987413786562557}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'area_se', 'smoothness_worst'), 'value': 0.5893254172273397}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_se', 'smoothness_worst'), 'value': 0.6278189270348933}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'compactness_se', 'smoothness_worst'), 'value': 0.6148651315178376}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'concavity_se', 'smoothness_worst'), 'value': 0.601916487605556}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'concave points_se', 'smoothness_worst'), 'value': 0.6211617929425634}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'symmetry_se', 'smoothness_worst'), 'value': 0.6260015454137712}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_se', 'smoothness_worst'), 'value': 0.6100561237210042}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'radius_worst', 'smoothness_worst'), 'value': 0.6126205849141098}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'texture_worst', 'smoothness_worst'), 'value': 0.6297785048880314}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'perimeter_worst', 'smoothness_worst'), 'value': 0.6116854412560152}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'area_worst', 'smoothness_worst'), 'value': 0.6013420073446673}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_worst', 'compactness_worst'), 'value': 0.6111962751451521}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_worst', 'concavity_worst'), 'value': 0.604126341281015}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_worst', 'concave points_worst'), 'value': 0.6091578308705945}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_worst', 'symmetry_worst'), 'value': 0.6264967418589424}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_worst', 'fractal_dimension_worst'), 'value': 0.6191316945227152}
# {'attributes': ('radius_mean', 'smoothness_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6182182090255934}
# {'attributes': ('texture_mean', 'smoothness_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6285492899193722}
# {'attributes': ('perimeter_mean', 'smoothness_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6171053059291495}
# {'attributes': ('area_mean', 'smoothness_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6072005407423638}
# {'attributes': ('smoothness_mean', 'compactness_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.614161960793369}
# {'attributes': ('smoothness_mean', 'concavity_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.5960928169073926}
# {'attributes': ('smoothness_mean', 'concave points_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.5984337114455056}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'radius_se', 'smoothness_worst'), 'value': 0.5980038697982166}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'texture_se', 'smoothness_worst'), 'value': 0.6251425140561294}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'perimeter_se', 'smoothness_worst'), 'value': 0.5976594373143577}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'area_se', 'smoothness_worst'), 'value': 0.5882434758854417}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_se', 'smoothness_worst'), 'value': 0.6267369856929952}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'compactness_se', 'smoothness_worst'), 'value': 0.6137831901759395}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'concavity_se', 'smoothness_worst'), 'value': 0.600834546263658}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'concave points_se', 'smoothness_worst'), 'value': 0.6200798516006653}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'symmetry_se', 'smoothness_worst'), 'value': 0.6249196040718731}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'fractal_dimension_se', 'smoothness_worst'), 'value': 0.608974182379106}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'radius_worst', 'smoothness_worst'), 'value': 0.6115386435722117}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'texture_worst', 'smoothness_worst'), 'value': 0.6286965635461335}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'perimeter_worst', 'smoothness_worst'), 'value': 0.6106034999141171}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'area_worst', 'smoothness_worst'), 'value': 0.6002600660027692}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_worst', 'compactness_worst'), 'value': 0.610114333803254}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_worst', 'concavity_worst'), 'value': 0.6030443999391171}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_worst', 'concave points_worst'), 'value': 0.6080758895286965}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_worst', 'symmetry_worst'), 'value': 0.6254148005170443}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean', 'smoothness_worst', 'fractal_dimension_worst'), 'value': 0.6180497531808171}
# {'attributes': ('radius_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6165781892293457}
# {'attributes': ('texture_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6269092701231246}
# {'attributes': ('perimeter_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6154652861329017}
# {'attributes': ('area_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6055605209461162}
# {'attributes': ('compactness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6125219409971213}
# {'attributes': ('concavity_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.594452797111145}
# {'attributes': ('concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.5967936916492579}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'smoothness_worst'), 'value': 0.596363850001969}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'smoothness_worst'), 'value': 0.6235024942598818}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'perimeter_se', 'smoothness_worst'), 'value': 0.59601941751811}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'area_se', 'smoothness_worst'), 'value': 0.5866034560891941}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'smoothness_worst'), 'value': 0.6250969658967476}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'compactness_se', 'smoothness_worst'), 'value': 0.6121431703796919}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'concavity_se', 'smoothness_worst'), 'value': 0.5991945264674103}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'concave points_se', 'smoothness_worst'), 'value': 0.6184398318044176}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'symmetry_se', 'smoothness_worst'), 'value': 0.6232795842756255}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'fractal_dimension_se', 'smoothness_worst'), 'value': 0.6073341625828584}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'radius_worst', 'smoothness_worst'), 'value': 0.609898623775964}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'texture_worst', 'smoothness_worst'), 'value': 0.6270565437498858}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'perimeter_worst', 'smoothness_worst'), 'value': 0.6089634801178695}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'area_worst', 'smoothness_worst'), 'value': 0.5986200462065215}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst', 'compactness_worst'), 'value': 0.6084743140070064}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst', 'concavity_worst'), 'value': 0.6014043801428695}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst', 'concave points_worst'), 'value': 0.6064358697324489}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst', 'symmetry_worst'), 'value': 0.6237747807207967}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst', 'fractal_dimension_worst'), 'value': 0.6164097333845695}
# ========================================== find best value ===================================
# [{'attributes': ('smoothness_mean', 'symmetry_mean', 'texture_worst', 'smoothness_worst'), 'value': 0.6297785048880314}]
# =============================================================================================
# sbs check: [{'attributes': ('smoothness_mean', 'symmetry_mean', 'texture_worst', 'smoothness_worst'), 'value': 0.6297785048880314}]
# current best [{'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6363894636851197}]
# current best_subset_score -----> [[{'attributes': ('smoothness_mean',), 'value': 0.644291062764079}], [{'attributes': ('smoothness_mean', 'symmetry_mean'), 'value': 0.6410110231715836}], [{'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.6384750881848879}], [{'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6363894636851197}]]
# ------------------------------------------calculate sbs check------------------------------------------
#
# combination_hist:=====================> [('radius_mean', 'smoothness_mean'), ('texture_mean', 'smoothness_mean'), ('perimeter_mean', 'smoothness_mean'), ('area_mean', 'smoothness_mean'), ('smoothness_mean', 'compactness_mean'), ('smoothness_mean', 'concavity_mean'), ('smoothness_mean', 'concave points_mean'), ('smoothness_mean', 'symmetry_mean'), ('smoothness_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'radius_se'), ('smoothness_mean', 'texture_se'), ('smoothness_mean', 'perimeter_se'), ('smoothness_mean', 'area_se'), ('smoothness_mean', 'smoothness_se'), ('smoothness_mean', 'compactness_se'), ('smoothness_mean', 'concavity_se'), ('smoothness_mean', 'concave points_se'), ('smoothness_mean', 'symmetry_se'), ('smoothness_mean', 'fractal_dimension_se'), ('smoothness_mean', 'radius_worst'), ('smoothness_mean', 'texture_worst'), ('smoothness_mean', 'perimeter_worst'), ('smoothness_mean', 'area_worst'), ('smoothness_mean', 'smoothness_worst'), ('smoothness_mean', 'compactness_worst'), ('smoothness_mean', 'concavity_worst'), ('smoothness_mean', 'concave points_worst'), ('smoothness_mean', 'symmetry_worst'), ('smoothness_mean', 'fractal_dimension_worst'), ('radius_mean', 'smoothness_mean', 'symmetry_mean'), ('texture_mean', 'smoothness_mean', 'symmetry_mean'), ('perimeter_mean', 'smoothness_mean', 'symmetry_mean'), ('area_mean', 'smoothness_mean', 'symmetry_mean'), ('smoothness_mean', 'compactness_mean', 'symmetry_mean'), ('smoothness_mean', 'concavity_mean', 'symmetry_mean'), ('smoothness_mean', 'concave points_mean', 'symmetry_mean'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'symmetry_mean', 'radius_se'), ('smoothness_mean', 'symmetry_mean', 'texture_se'), ('smoothness_mean', 'symmetry_mean', 'perimeter_se'), ('smoothness_mean', 'symmetry_mean', 'area_se'), ('smoothness_mean', 'symmetry_mean', 'smoothness_se'), ('smoothness_mean', 'symmetry_mean', 'compactness_se'), ('smoothness_mean', 'symmetry_mean', 'concavity_se'), ('smoothness_mean', 'symmetry_mean', 'concave points_se'), ('smoothness_mean', 'symmetry_mean', 'symmetry_se'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_se'), ('smoothness_mean', 'symmetry_mean', 'radius_worst'), ('smoothness_mean', 'symmetry_mean', 'texture_worst'), ('smoothness_mean', 'symmetry_mean', 'perimeter_worst'), ('smoothness_mean', 'symmetry_mean', 'area_worst'), ('smoothness_mean', 'symmetry_mean', 'smoothness_worst'), ('smoothness_mean', 'symmetry_mean', 'compactness_worst'), ('smoothness_mean', 'symmetry_mean', 'concavity_worst'), ('smoothness_mean', 'symmetry_mean', 'concave points_worst'), ('smoothness_mean', 'symmetry_mean', 'symmetry_worst'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_worst'), ('radius_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), ('texture_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), ('perimeter_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), ('area_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'compactness_mean', 'symmetry_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'concavity_mean', 'symmetry_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'perimeter_se'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'area_se'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'compactness_se'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'concavity_se'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'concave points_se'), ('smoothness_mean', 'symmetry_mean', 'frac ...
#
# {'attributes': ('radius_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6221207639362925}
# {'attributes': ('texture_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6303856286513154}
# {'attributes': ('perimeter_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6212304414591372}
# {'attributes': ('area_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6133066293097087}
# {'attributes': ('smoothness_mean', 'compactness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6188757653505129}
# {'attributes': ('smoothness_mean', 'concavity_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6044204502417317}
# {'attributes': ('smoothness_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6062931658722222}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'smoothness_worst'), 'value': 0.605949292554391}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'smoothness_worst'), 'value': 0.6276602079607212}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'perimeter_se', 'smoothness_worst'), 'value': 0.6056737465673038}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'area_se', 'smoothness_worst'), 'value': 0.598140977424171}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'smoothness_worst'), 'value': 0.6289357852702138}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'compactness_se', 'smoothness_worst'), 'value': 0.6185727488565693}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'concavity_se', 'smoothness_worst'), 'value': 0.608213833726744}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'concave points_se', 'smoothness_worst'), 'value': 0.6236100779963498}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'symmetry_se', 'smoothness_worst'), 'value': 0.6274818799733162}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'fractal_dimension_se', 'smoothness_worst'), 'value': 0.6147255426191025}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_worst', 'smoothness_worst'), 'value': 0.616777111573587}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_worst', 'smoothness_worst'), 'value': 0.6305034475527245}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'perimeter_worst', 'smoothness_worst'), 'value': 0.6160289966471113}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'area_worst', 'smoothness_worst'), 'value': 0.607754249518033}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst', 'compactness_worst'), 'value': 0.6156376637584209}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst', 'concavity_worst'), 'value': 0.6099817166671112}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst', 'concave points_worst'), 'value': 0.6140069083387749}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst', 'symmetry_worst'), 'value': 0.6278780371294532}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst', 'fractal_dimension_worst'), 'value': 0.6219859992604715}
# ========================================== find best value ===================================
# [{'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_worst', 'smoothness_worst'), 'value': 0.6305034475527245}]
# =============================================================================================
#
# ========================================== Subset_Score Round 6 =============================
#
# combination of previous round:===========> [('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_worst'), ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), ('smoothness_mean', 'symmetry_mean', 'texture_worst', 'smoothness_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'texture_worst', 'smoothness_worst'), ('symmetry_mean', 'fractal_dimension_mean', 'texture_worst', 'smoothness_worst')]
# never occured combination:===============> [('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), ('smoothness_mean', 'symmetry_mean', 'texture_worst', 'smoothness_worst'), ('smoothness_mean', 'fractal_dimension_mean', 'texture_worst', 'smoothness_worst'), ('symmetry_mean', 'fractal_dimension_mean', 'texture_worst', 'smoothness_worst')]
# ------------------------------------------calculate sbs check------------------------------------------
# ...
#
# {'attributes': ('radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst'), 'value': 0.5513936324188493}
# ========================================== find best value ===================================
# [{'attributes': ('radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst'), 'value': 0.5513936324188493}]
# =============================================================================================
#
#
# best_subset_per_round :
#  =============== SubsetRanking ===============
# [{'attributes': ('smoothness_mean',), 'value': 0.644291062764079},
#  {'attributes': ('smoothness_mean', 'symmetry_mean'),
#   'value': 0.6410110231715836},
#  {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'),
#   'value': 0.6384750881848879},
#  {'attributes': ('smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'smoothness_worst'),
#   'value': 0.6363894636851197},
#  {'attributes': ('smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_worst',
#    'smoothness_worst'),
#   'value': 0.6305034475527245},
#  {'attributes': ('texture_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_worst',
#    'smoothness_worst'),
#   'value': 0.6264812543799534},
#  {'attributes': ('texture_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'smoothness_se',
#    'texture_worst',
#    'smoothness_worst'),
#   'value': 0.6225726568414729},
#  {'attributes': ('texture_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'smoothness_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst'),
#   'value': 0.6189801160996371},
#  {'attributes': ('texture_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst'),
#   'value': 0.616064901540025},
#  {'attributes': ('texture_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'symmetry_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst'),
#   'value': 0.6136435658986327},
#  {'attributes': ('texture_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'concave points_se',
#    'symmetry_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst'),
#   'value': 0.6099025631115997},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'concave points_se',
#    'symmetry_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst'),
#   'value': 0.6061645132640483},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'concave points_se',
#    'symmetry_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.6029497154408044},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'concave points_se',
#    'symmetry_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5999243323775475},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'concave points_se',
#    'symmetry_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5965174416865167},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concave points_se',
#    'symmetry_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5934417196775074},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concave points_se',
#    'symmetry_se',
#    'radius_worst',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5901997187039749},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concave points_se',
#    'symmetry_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'smoothness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5871101303590363},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concave points_se',
#    'symmetry_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5842427795007514},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5814341334434654},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concave points_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5787218740867954},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concave points_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5760970294377622},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concavity_worst',
#    'concave points_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5729776250532977},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concavity_worst',
#    'concave points_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5697498620882955},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'area_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concavity_worst',
#    'concave points_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.566688403318751},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'concave points_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'area_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concavity_worst',
#    'concave points_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5635814637534388},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'concave points_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'radius_se',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'area_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concavity_worst',
#    'concave points_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5606409876155882},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'concave points_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'radius_se',
#    'texture_se',
#    'perimeter_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'area_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concavity_worst',
#    'concave points_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.557861340847033},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'concavity_mean',
#    'concave points_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'radius_se',
#    'texture_se',
#    'perimeter_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'area_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concavity_worst',
#    'concave points_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.555057308282245},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'concavity_mean',
#    'concave points_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'radius_se',
#    'texture_se',
#    'perimeter_se',
#    'area_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'area_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concavity_worst',
#    'concave points_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5513936324188493}]

# %% [markdown]
# <h2> The Best Candidate Subset by SFFS

# %%
find_best_subset(best_subset_per_round)
# Out:
# ========================================== find best value ===================================
# [{'attributes': ('smoothness_mean',), 'value': 0.644291062764079}]
# =============================================================================================
# [{'attributes': ('smoothness_mean',), 'value': 0.644291062764079}]
