# %%
#library
import pandas as pd
import numpy as np
import itertools
import seaborn as sns
import math

# %% [markdown]
# <H1>Dataset : Breast Cancer

# %%
df = pd.read_csv("../dataset/breast_cancer.csv")
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          17.33           184.60      2019.0           0.16220
# 1    ...          23.41           158.80      1956.0           0.12380
# 2    ...          25.53           152.50      1709.0           0.14440
# 3    ...          26.50            98.87       567.7           0.20980
# 4    ...          16.67           152.20      1575.0           0.13740
# ..   ...            ...              ...         ...               ...
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.11890          NaN
# 1                    0.08902          NaN
# 2                    0.08758          NaN
# 3                    0.17300          NaN
# 4                    0.07678          NaN
# ..                       ...          ...
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
#turn M = 1 B = 0
df["diagnosis"] = df['diagnosis'].apply(lambda i : 1 if i == 'M' else 0)
df
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# 1       1326.0          0.08474           0.07864         0.08690
# 2       1203.0          0.10960           0.15990         0.19740
# 3        386.1          0.14250           0.28390         0.24140
# 4       1297.0          0.10030           0.13280         0.19800
# ..         ...              ...               ...             ...
# 564     1479.0          0.11100           0.11590         0.24390
# 565     1261.0          0.09780           0.10340         0.14400
# 566      858.1          0.08455           0.10230         0.09251
# 567     1265.0          0.11780           0.27700         0.35140
# 568      181.0          0.05263           0.04362         0.00000
#
#      concave points_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0                0.14710  ...          17.33           184.60      2019.0
# 1                0.07017  ...          23.41           158.80      1956.0
# 2                0.12790  ...          25.53           152.50      1709.0
# 3                0.10520  ...          26.50            98.87       567.7
# 4                0.10430  ...          16.67           152.20      1575.0
# ..                   ...  ...            ...              ...         ...
# 564              0.13890  ...          26.40           166.10      2027.0
# 565              0.09791  ...          38.25           155.00      1731.0
# 566              0.05302  ...          34.12           126.70      1124.0
# 567              0.15200  ...          39.42           184.60      1821.0
# 568              0.00000  ...          30.37            59.16       268.6
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst  \
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
#      Unnamed: 32
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 564          NaN
# 565          NaN
# 566          NaN
# 567          NaN
# 568          NaN
#
# [569 rows x 33 columns]

# %% [markdown]
# <h1>Features

# %%
features = df.columns.tolist()[2:-1]
features
# Out:
# ['radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'radius_se',
#  'texture_se',
#  'perimeter_se',
#  'area_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave points_se',
#  'symmetry_se',
#  'fractal_dimension_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst',
#  'concave points_worst',
#  'symmetry_worst',
#  'fractal_dimension_worst']

# %%
X = df[features]
X
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 0                   0.07871  ...        25.380          17.33
# 1                   0.05667  ...        24.990          23.41
# 2                   0.05999  ...        23.570          25.53
# 3                   0.09744  ...        14.910          26.50
# 4                   0.05883  ...        22.540          16.67
# ..                      ...  ...           ...            ...
# 564                 0.05623  ...        25.450          26.40
# 565                 0.05533  ...        23.690          38.25
# 566                 0.05648  ...        18.980          34.12
# 567                 0.07016  ...        25.740          39.42
# 568                 0.05884  ...         9.456          30.37
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0             184.60      2019.0           0.16220            0.66560
# 1             158.80      1956.0           0.12380            0.18660
# 2             152.50      1709.0           0.14440            0.42450
# 3              98.87       567.7           0.20980            0.86630
# 4             152.20      1575.0           0.13740            0.20500
# ..               ...         ...               ...                ...
# 564           166.10      2027.0           0.14100            0.21130
# 565           155.00      1731.0           0.11660            0.19220
# 566           126.70      1124.0           0.11390            0.30940
# 567           184.60      1821.0           0.16500            0.86810
# 568            59.16       268.6           0.08996            0.06444
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.7119                0.2654          0.4601
# 1             0.2416                0.1860          0.2750
# 2             0.4504                0.2430          0.3613
# 3             0.6869                0.2575          0.6638
# 4             0.4000                0.1625          0.2364
# ..               ...                   ...             ...
# 564           0.4107                0.2216          0.2060
# 565           0.3215                0.1628          0.2572
# 566           0.3403                0.1418          0.2218
# 567           0.9387                0.2650          0.4087
# 568           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 564                  0.07115
# 565                  0.06637
# 566                  0.07820
# 567                  0.12400
# 568                  0.07039
#
# [569 rows x 30 columns]

# %% [markdown]
# <h2> Normalization Data

# %%
X = df[features].apply(lambda x: (x - x.min()) / (x.max() - x.min()))
X
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       0.521037      0.022658        0.545989   0.363733         0.593753
# 1       0.643144      0.272574        0.615783   0.501591         0.289880
# 2       0.601496      0.390260        0.595743   0.449417         0.514309
# 3       0.210090      0.360839        0.233501   0.102906         0.811321
# 4       0.629893      0.156578        0.630986   0.489290         0.430351
# ..           ...           ...             ...        ...              ...
# 564     0.690000      0.428813        0.678668   0.566490         0.526948
# 565     0.622320      0.626987        0.604036   0.474019         0.407782
# 566     0.455251      0.621238        0.445788   0.303118         0.288165
# 567     0.644564      0.663510        0.665538   0.475716         0.588336
# 568     0.036869      0.501522        0.028540   0.015907         0.000000
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0            0.792037        0.703140             0.731113       0.686364
# 1            0.181768        0.203608             0.348757       0.379798
# 2            0.431017        0.462512             0.635686       0.509596
# 3            0.811361        0.565604             0.522863       0.776263
# 4            0.347893        0.463918             0.518390       0.378283
# ..                ...             ...                  ...            ...
# 564          0.296055        0.571462             0.690358       0.336364
# 565          0.257714        0.337395             0.486630       0.349495
# 566          0.254340        0.216753             0.263519       0.267677
# 567          0.790197        0.823336             0.755467       0.675253
# 568          0.074351        0.000000             0.000000       0.266162
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 0                  0.605518  ...      0.620776       0.141525
# 1                  0.141323  ...      0.606901       0.303571
# 2                  0.211247  ...      0.556386       0.360075
# 3                  1.000000  ...      0.248310       0.385928
# 4                  0.186816  ...      0.519744       0.123934
# ..                      ...  ...           ...            ...
# 564                0.132056  ...      0.623266       0.383262
# 565                0.113100  ...      0.560655       0.699094
# 566                0.137321  ...      0.393099       0.589019
# 567                0.425442  ...      0.633582       0.730277
# 568                0.187026  ...      0.054287       0.489072
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0           0.668310    0.450698          0.601136           0.619292
# 1           0.539818    0.435214          0.347553           0.154563
# 2           0.508442    0.374508          0.483590           0.385375
# 3           0.241347    0.094008          0.915472           0.814012
# 4           0.506948    0.341575          0.437364           0.172415
# ..               ...         ...               ...                ...
# 564         0.576174    0.452664          0.461137           0.178527
# 565         0.520892    0.379915          0.300007           0.159997
# 566         0.379949    0.230731          0.282177           0.273705
# 567         0.668310    0.402035          0.619626           0.815758
# 568         0.043578    0.020497          0.124084           0.036043
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 0           0.568610              0.912027        0.598462
# 1           0.192971              0.639175        0.233590
# 2           0.359744              0.835052        0.403706
# 3           0.548642              0.884880        1.000000
# 4           0.319489              0.558419        0.157500
# ..               ...                   ...             ...
# 564         0.328035              0.761512        0.097575
# 565         0.256789              0.559450        0.198502
# 566         0.271805              0.487285        0.128721
# 567         0.749760              0.910653        0.497142
# 568         0.000000              0.000000        0.257441
#
#      fractal_dimension_worst
# 0                   0.418864
# 1                   0.222878
# 2                   0.213433
# 3                   0.773711
# 4                   0.142595
# ..                       ...
# 564                 0.105667
# 565                 0.074315
# 566                 0.151909
# 567                 0.452315
# 568                 0.100682
#
# [569 rows x 30 columns]

# %%
label = 'diagnosis'
label
# Out:
# 'diagnosis'

# %%
y = df['diagnosis']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int64

# %%
num_feats = X.shape[1]
num_feats
# Out:
# 30

# %% [markdown]
# <h2> Manhattan Distance Table

# %%
df_md = {label: []}

for f in features:
    df_md[label].append(np.mean([math.sqrt(abs(a[0]-a[1])) for a in zip(X[f], y)]))

df_md = pd.DataFrame.from_dict(df_md)
df_md.index = features
df_md
# Out:
#                          diagnosis
# radius_mean               0.565046
# texture_mean              0.606370
# perimeter_mean            0.560594
# area_mean                 0.520975
# smoothness_mean           0.644291
# compactness_mean          0.548821
# concavity_mean            0.476544
# concave points_mean       0.485908
# symmetry_mean             0.637731
# fractal_dimension_mean    0.633403
# radius_se                 0.484189
# texture_se                0.592743
# perimeter_se              0.482811
# area_se                   0.445147
# smoothness_se             0.599121
# compactness_se            0.547306
# concavity_se              0.495511
# concave points_se         0.572493
# symmetry_se               0.591852
# fractal_dimension_se      0.528070
# radius_worst              0.538328
# texture_worst             0.606959
# perimeter_worst           0.534587
# area_worst                0.493213
# smoothness_worst          0.630133
# compactness_worst         0.532630
# concavity_worst           0.504351
# concave points_worst      0.524477
# symmetry_worst            0.593832
# fractal_dimension_worst   0.564372

# %% [markdown]
# <h1>Function

# %%
def grouping_attribute_score(attrubutes, value):
    '''combine value to dictionary format'''
    return {"attributes": attrubutes, "value": value}

# %%
def find_best_subset(subset_score, max_min='max'):
    """find best score of subset subset score is list of grouping_attribute_score
        max_min (str) : can be only 'max' or 'min' to define the best value
    """
    #still available for only a group of attributes
    print('========================================== find best value ===================================')
    best_subset_score = []
    
    if max_min == 'min':
        # min is the best
        subset_score.sort(key=lambda x: x['value'], reverse=False)
    else:        
        #max is the best
        subset_score.sort(key=lambda x: x['value'], reverse=True)

    best_subset_score.append(subset_score[0])
    print(best_subset_score)
    print("=============================================================================================")
    return best_subset_score
# return [{'attrubute': ('Glucose', 'BMI'), 'value': 0.3796380304756596}]

# %%
def cal_best(algo_round, max_min='max'):
    """match all subset and find the best one
        max_min (str) : can be only 'max' or 'min' to define the best value
    """
    #start calculating
    subset_score = []
    subset_mean = []
    
    #use mean of all manhattan distance of subset
    for atrs in algo_round:
        temp_score_mean = []
        for i in atrs:
            #manhattan distance
            md = df_md[label][i]
            temp_score_mean.append(md)
        subset_mean.append(np.mean(temp_score_mean)) #score
        
    for atrs,mean_score in zip(algo_round,subset_mean):
        subset_score.append(grouping_attribute_score(atrs, mean_score))
    [print(i) for i in subset_score]
    return find_best_subset(subset_score=subset_score, max_min=max_min)

# %% [markdown]
# <h1>SFS

# %%
best_subset_per_round = []
for num in range(2, num_feats+1):
    print("========================================== Subset_Score Round", num-1,'=============================')
    if num == 2: #1st round
        #combination of subset in each round
        sfs_round = list(itertools.combinations(features, num))

        print()        
        best_subset_per_round.append(cal_best(algo_round=sfs_round, max_min='max'))
        print()
        
    else: #other round
        #combination of subset in each round
        sfs_round = list(itertools.combinations(features, num))
        
        #hv to pop non best_subset out
        sfs_round_temp = []
        for i in range(len(sfs_round)):
            if all(attr in sfs_round[i] for attr in best_subset_per_round[num-3][0]['attributes']):
                sfs_round_temp.append(sfs_round[i])
        sfs_round = sfs_round_temp
        
        print()
        best_subset_per_round.append(cal_best(algo_round=sfs_round, max_min='max'))
        print()       
        
print()
print('best_subset_per_round :',"\n", '=============== SubsetRanking ===============')
# [print(i) for i in best_subset_per_round]

best_temp = [i[0] for i in best_subset_per_round]
best_subset_per_round = best_temp
best_subset_per_round.sort(key=lambda x: x['value'], reverse=True) # max is the best
best_subset_per_round
# Out:
# ========================================== Subset_Score Round 1 =============================
#
# {'attributes': ('radius_mean', 'texture_mean'), 'value': 0.5857081267285404}
# {'attributes': ('radius_mean', 'perimeter_mean'), 'value': 0.562820158748095}
# {'attributes': ('radius_mean', 'area_mean'), 'value': 0.5430106283745237}
# {'attributes': ('radius_mean', 'smoothness_mean'), 'value': 0.604668513852531}
# {'attributes': ('radius_mean', 'compactness_mean'), 'value': 0.5569334684765341}
# {'attributes': ('radius_mean', 'concavity_mean'), 'value': 0.5207951807045812}
# {'attributes': ('radius_mean', 'concave points_mean'), 'value': 0.5254769697808073}
# {'attributes': ('radius_mean', 'symmetry_mean'), 'value': 0.6013884742600355}
# {'attributes': ('radius_mean', 'fractal_dimension_mean'), 'value': 0.5992245915762395}
# {'attributes': ('radius_mean', 'radius_se'), 'value': 0.5246172864862293}
# {'attributes': ('radius_mean', 'texture_se'), 'value': 0.5788945750020549}
# {'attributes': ('radius_mean', 'perimeter_se'), 'value': 0.5239284215185115}
# {'attributes': ('radius_mean', 'area_se'), 'value': 0.5050964986606795}
# {'attributes': ('radius_mean', 'smoothness_se'), 'value': 0.5820835182757865}
# {'attributes': ('radius_mean', 'compactness_se'), 'value': 0.5561759272416753}
# {'attributes': ('radius_mean', 'concavity_se'), 'value': 0.5302786394171121}
# {'attributes': ('radius_mean', 'concave points_se'), 'value': 0.5687692500911268}
# {'attributes': ('radius_mean', 'symmetry_se'), 'value': 0.5784487550335424}
# {'attributes': ('radius_mean', 'fractal_dimension_se'), 'value': 0.5465579116480083}
# {'attributes': ('radius_mean', 'radius_worst'), 'value': 0.5516868340342195}
# {'attributes': ('radius_mean', 'texture_worst'), 'value': 0.586002673982063}
# {'attributes': ('radius_mean', 'perimeter_worst'), 'value': 0.5498165467180305}
# {'attributes': ('radius_mean', 'area_worst'), 'value': 0.5291296788953345}
# {'attributes': ('radius_mean', 'smoothness_worst'), 'value': 0.5975892775633991}
# {'attributes': ('radius_mean', 'compactness_worst'), 'value': 0.5488382144963042}
# {'attributes': ('radius_mean', 'concavity_worst'), 'value': 0.5346983467680302}
# {'attributes': ('radius_mean', 'concave points_worst'), 'value': 0.5447613259471891}
# {'attributes': ('radius_mean', 'symmetry_worst'), 'value': 0.579439147923885}
# {'attributes': ('radius_mean', 'fractal_dimension_worst'), 'value': 0.5647090532514305}
# {'attributes': ('texture_mean', 'perimeter_mean'), 'value': 0.5834823205356526}
# {'attributes': ('texture_mean', 'area_mean'), 'value': 0.5636727901620815}
# {'attributes': ('texture_mean', 'smoothness_mean'), 'value': 0.6253306756400886}
# {'attributes': ('texture_mean', 'compactness_mean'), 'value': 0.5775956302640918}
# {'attributes': ('texture_mean', 'concavity_mean'), 'value': 0.541457342492139}
# {'attributes': ('texture_mean', 'concave points_mean'), 'value': 0.5461391315683649}
# {'attributes': ('texture_mean', 'symmetry_mean'), 'value': 0.6220506360475933}
# {'attributes': ('texture_mean', 'fractal_dimension_mean'), 'value': 0.6198867533637973}
# {'attributes': ('texture_mean', 'radius_se'), 'value': 0.545279448273787}
# {'attributes': ('texture_mean', 'texture_se'), 'value': 0.5995567367896126}
# {'attributes': ('texture_mean', 'perimeter_se'), 'value': 0.5445905833060691}
# {'attributes': ('texture_mean', 'area_se'), 'value': 0.5257586604482372}
# {'attributes': ('texture_mean', 'smoothness_se'), 'value': 0.6027456800633442}
# {'attributes': ('texture_mean', 'compactness_se'), 'value': 0.576838089029233}
# {'attributes': ('texture_mean', 'concavity_se'), 'value': 0.5509408012046698}
# {'attributes': ('texture_mean', 'concave points_se'), 'value': 0.5894314118786844}
# {'attributes': ('texture_mean', 'symmetry_se'), 'value': 0.5991109168211001}
# {'attributes': ('texture_mean', 'fractal_dimension_se'), 'value': 0.5672200734355659}
# {'attributes': ('texture_mean', 'radius_worst'), 'value': 0.5723489958217771}
# {'attributes': ('texture_mean', 'texture_worst'), 'value': 0.6066648357696207}
# {'attributes': ('texture_mean', 'perimeter_worst'), 'value': 0.5704787085055881}
# {'attributes': ('texture_mean', 'area_worst'), 'value': 0.5497918406828921}
# {'attributes': ('texture_mean', 'smoothness_worst'), 'value': 0.6182514393509568}
# {'attributes': ('texture_mean', 'compactness_worst'), 'value': 0.5695003762838619}
# {'attributes': ('texture_mean', 'concavity_worst'), 'value': 0.5553605085555878}
# {'attributes': ('texture_mean', 'concave points_worst'), 'value': 0.5654234877347468}
# {'attributes': ('texture_mean', 'symmetry_worst'), 'value': 0.6001013097114426}
# {'attributes': ('texture_mean', 'fractal_dimension_worst'), 'value': 0.5853712150389881}
# {'attributes': ('perimeter_mean', 'area_mean'), 'value': 0.5407848221816359}
# {'attributes': ('perimeter_mean', 'smoothness_mean'), 'value': 0.602442707659643}
# {'attributes': ('perimeter_mean', 'compactness_mean'), 'value': 0.5547076622836462}
# {'attributes': ('perimeter_mean', 'concavity_mean'), 'value': 0.5185693745116933}
# {'attributes': ('perimeter_mean', 'concave points_mean'), 'value': 0.5232511635879193}
# {'attributes': ('perimeter_mean', 'symmetry_mean'), 'value': 0.5991626680671477}
# {'attributes': ('perimeter_mean', 'fractal_dimension_mean'), 'value': 0.5969987853833516}
# {'attributes': ('perimeter_mean', 'radius_se'), 'value': 0.5223914802933415}
# {'attributes': ('perimeter_mean', 'texture_se'), 'value': 0.576668768809167}
# {'attributes': ('perimeter_mean', 'perimeter_se'), 'value': 0.5217026153256236}
# {'attributes': ('perimeter_mean', 'area_se'), 'value': 0.5028706924677916}
# {'attributes': ('perimeter_mean', 'smoothness_se'), 'value': 0.5798577120828987}
# {'attributes': ('perimeter_mean', 'compactness_se'), 'value': 0.5539501210487874}
# {'attributes': ('perimeter_mean', 'concavity_se'), 'value': 0.5280528332242242}
# {'attributes': ('perimeter_mean', 'concave points_se'), 'value': 0.5665434438982389}
# {'attributes': ('perimeter_mean', 'symmetry_se'), 'value': 0.5762229488406545}
# {'attributes': ('perimeter_mean', 'fractal_dimension_se'), 'value': 0.5443321054551205}
# {'attributes': ('perimeter_mean', 'radius_worst'), 'value': 0.5494610278413317}
# {'attributes': ('perimeter_mean', 'texture_worst'), 'value': 0.583776867789175}
# {'attributes': ('perimeter_mean', 'perimeter_worst'), 'value': 0.5475907405251426}
# {'attributes': ('perimeter_mean', 'area_worst'), 'value': 0.5269038727024467}
# {'attributes': ('perimeter_mean', 'smoothness_worst'), 'value': 0.5953634713705112}
# {'attributes': ('perimeter_mean', 'compactness_worst'), 'value': 0.5466124083034163}
# {'attributes': ('perimeter_mean', 'concavity_worst'), 'value': 0.5324725405751423}
# {'attributes': ('perimeter_mean', 'concave points_worst'), 'value': 0.5425355197543011}
# {'attributes': ('perimeter_mean', 'symmetry_worst'), 'value': 0.577213341730997}
# {'attributes': ('perimeter_mean', 'fractal_dimension_worst'), 'value': 0.5624832470585426}
# {'attributes': ('area_mean', 'smoothness_mean'), 'value': 0.5826331772860719}
# {'attributes': ('area_mean', 'compactness_mean'), 'value': 0.5348981319100751}
# {'attributes': ('area_mean', 'concavity_mean'), 'value': 0.4987598441381222}
# {'attributes': ('area_mean', 'concave points_mean'), 'value': 0.5034416332143482}
# {'attributes': ('area_mean', 'symmetry_mean'), 'value': 0.5793531376935765}
# {'attributes': ('area_mean', 'fractal_dimension_mean'), 'value': 0.5771892550097806}
# {'attributes': ('area_mean', 'radius_se'), 'value': 0.5025819499197703}
# {'attributes': ('area_mean', 'texture_se'), 'value': 0.5568592384355959}
# {'attributes': ('area_mean', 'perimeter_se'), 'value': 0.5018930849520524}
# {'attributes': ('area_mean', 'area_se'), 'value': 0.48306116209422045}
# {'attributes': ('area_mean', 'smoothness_se'), 'value': 0.5600481817093275}
# {'attributes': ('area_mean', 'compactness_se'), 'value': 0.5341405906752162}
# {'attributes': ('area_mean', 'concavity_se'), 'value': 0.5082433028506531}
# {'attributes': ('area_mean', 'concave points_se'), 'value': 0.5467339135246677}
# {'attributes': ('area_mean', 'symmetry_se'), 'value': 0.5564134184670834}
# {'attributes': ('area_mean', 'fractal_dimension_se'), 'value': 0.5245225750815492}
# {'attributes': ('area_mean', 'radius_worst'), 'value': 0.5296514974677604}
# {'attributes': ('area_mean', 'texture_worst'), 'value': 0.563967337415604}
# {'attributes': ('area_mean', 'perimeter_worst'), 'value': 0.5277812101515714}
# {'attributes': ('area_mean', 'area_worst'), 'value': 0.5070943423288754}
# {'attributes': ('area_mean', 'smoothness_worst'), 'value': 0.5755539409969401}
# {'attributes': ('area_mean', 'compactness_worst'), 'value': 0.5268028779298451}
# {'attributes': ('area_mean', 'concavity_worst'), 'value': 0.5126630102015711}
# {'attributes': ('area_mean', 'concave points_worst'), 'value': 0.5227259893807301}
# {'attributes': ('area_mean', 'symmetry_worst'), 'value': 0.5574038113574259}
# {'attributes': ('area_mean', 'fractal_dimension_worst'), 'value': 0.5426737166849714}
# {'attributes': ('smoothness_mean', 'compactness_mean'), 'value': 0.5965560173880822}
# {'attributes': ('smoothness_mean', 'concavity_mean'), 'value': 0.5604177296161292}
# {'attributes': ('smoothness_mean', 'concave points_mean'), 'value': 0.5650995186923553}
# {'attributes': ('smoothness_mean', 'symmetry_mean'), 'value': 0.6410110231715836}
# {'attributes': ('smoothness_mean', 'fractal_dimension_mean'), 'value': 0.6388471404877876}
# {'attributes': ('smoothness_mean', 'radius_se'), 'value': 0.5642398353977774}
# {'attributes': ('smoothness_mean', 'texture_se'), 'value': 0.6185171239136029}
# {'attributes': ('smoothness_mean', 'perimeter_se'), 'value': 0.5635509704300595}
# {'attributes': ('smoothness_mean', 'area_se'), 'value': 0.5447190475722276}
# {'attributes': ('smoothness_mean', 'smoothness_se'), 'value': 0.6217060671873347}
# {'attributes': ('smoothness_mean', 'compactness_se'), 'value': 0.5957984761532233}
# {'attributes': ('smoothness_mean', 'concavity_se'), 'value': 0.5699011883286602}
# {'attributes': ('smoothness_mean', 'concave points_se'), 'value': 0.6083917990026748}
# {'attributes': ('smoothness_mean', 'symmetry_se'), 'value': 0.6180713039450905}
# {'attributes': ('smoothness_mean', 'fractal_dimension_se'), 'value': 0.5861804605595564}
# {'attributes': ('smoothness_mean', 'radius_worst'), 'value': 0.5913093829457676}
# {'attributes': ('smoothness_mean', 'texture_worst'), 'value': 0.625625222893611}
# {'attributes': ('smoothness_mean', 'perimeter_worst'), 'value': 0.5894390956295785}
# {'attributes': ('smoothness_mean', 'area_worst'), 'value': 0.5687522278068826}
# {'attributes': ('smoothness_mean', 'smoothness_worst'), 'value': 0.6372118264749471}
# {'attributes': ('smoothness_mean', 'compactness_worst'), 'value': 0.5884607634078522}
# {'attributes': ('smoothness_mean', 'concavity_worst'), 'value': 0.5743208956795782}
# {'attributes': ('smoothness_mean', 'concave points_worst'), 'value': 0.5843838748587371}
# {'attributes': ('smoothness_mean', 'symmetry_worst'), 'value': 0.619061696835433}
# {'attributes': ('smoothness_mean', 'fractal_dimension_worst'), 'value': 0.6043316021629785}
# {'attributes': ('compactness_mean', 'concavity_mean'), 'value': 0.5126826842401324}
# {'attributes': ('compactness_mean', 'concave points_mean'), 'value': 0.5173644733163585}
# {'attributes': ('compactness_mean', 'symmetry_mean'), 'value': 0.5932759777955868}
# {'attributes': ('compactness_mean', 'fractal_dimension_mean'), 'value': 0.5911120951117907}
# {'attributes': ('compactness_mean', 'radius_se'), 'value': 0.5165047900217806}
# {'attributes': ('compactness_mean', 'texture_se'), 'value': 0.5707820785376061}
# {'attributes': ('compactness_mean', 'perimeter_se'), 'value': 0.5158159250540627}
# {'attributes': ('compactness_mean', 'area_se'), 'value': 0.49698400219623073}
# {'attributes': ('compactness_mean', 'smoothness_se'), 'value': 0.5739710218113379}
# {'attributes': ('compactness_mean', 'compactness_se'), 'value': 0.5480634307772265}
# {'attributes': ('compactness_mean', 'concavity_se'), 'value': 0.5221661429526634}
# {'attributes': ('compactness_mean', 'concave points_se'), 'value': 0.560656753626678}
# {'attributes': ('compactness_mean', 'symmetry_se'), 'value': 0.5703362585690936}
# {'attributes': ('compactness_mean', 'fractal_dimension_se'), 'value': 0.5384454151835596}
# {'attributes': ('compactness_mean', 'radius_worst'), 'value': 0.5435743375697708}
# {'attributes': ('compactness_mean', 'texture_worst'), 'value': 0.5778901775176142}
# {'attributes': ('compactness_mean', 'perimeter_worst'), 'value': 0.5417040502535817}
# {'attributes': ('compactness_mean', 'area_worst'), 'value': 0.5210171824308858}
# {'attributes': ('compactness_mean', 'smoothness_worst'), 'value': 0.5894767810989503}
# {'attributes': ('compactness_mean', 'compactness_worst'), 'value': 0.5407257180318554}
# {'attributes': ('compactness_mean', 'concavity_worst'), 'value': 0.5265858503035814}
# {'attributes': ('compactness_mean', 'concave points_worst'), 'value': 0.5366488294827403}
# {'attributes': ('compactness_mean', 'symmetry_worst'), 'value': 0.5713266514594362}
# {'attributes': ('compactness_mean', 'fractal_dimension_worst'), 'value': 0.5565965567869817}
# {'attributes': ('concavity_mean', 'concave points_mean'), 'value': 0.48122618554440566}
# {'attributes': ('concavity_mean', 'symmetry_mean'), 'value': 0.557137690023634}
# {'attributes': ('concavity_mean', 'fractal_dimension_mean'), 'value': 0.5549738073398379}
# {'attributes': ('concavity_mean', 'radius_se'), 'value': 0.4803665022498277}
# {'attributes': ('concavity_mean', 'texture_se'), 'value': 0.5346437907656533}
# {'attributes': ('concavity_mean', 'perimeter_se'), 'value': 0.4796776372821099}
# {'attributes': ('concavity_mean', 'area_se'), 'value': 0.4608457144242779}
# {'attributes': ('concavity_mean', 'smoothness_se'), 'value': 0.5378327340393849}
# {'attributes': ('concavity_mean', 'compactness_se'), 'value': 0.5119251430052736}
# {'attributes': ('concavity_mean', 'concavity_se'), 'value': 0.48602785518071046}
# {'attributes': ('concavity_mean', 'concave points_se'), 'value': 0.5245184658547251}
# {'attributes': ('concavity_mean', 'symmetry_se'), 'value': 0.5341979707971407}
# {'attributes': ('concavity_mean', 'fractal_dimension_se'), 'value': 0.5023071274116067}
# {'attributes': ('concavity_mean', 'radius_worst'), 'value': 0.5074360497978179}
# {'attributes': ('concavity_mean', 'texture_worst'), 'value': 0.5417518897456614}
# {'attributes': ('concavity_mean', 'perimeter_worst'), 'value': 0.5055657624816288}
# {'attributes': ('concavity_mean', 'area_worst'), 'value': 0.48487889465893286}
# {'attributes': ('concavity_mean', 'smoothness_worst'), 'value': 0.5533384933269975}
# {'attributes': ('concavity_mean', 'compactness_worst'), 'value': 0.5045874302599025}
# {'attributes': ('concavity_mean', 'concavity_worst'), 'value': 0.4904475625316285}
# {'attributes': ('concavity_mean', 'concave points_worst'), 'value': 0.5005105417107875}
# {'attributes': ('concavity_mean', 'symmetry_worst'), 'value': 0.5351883636874832}
# {'attributes': ('concavity_mean', 'fractal_dimension_worst'), 'value': 0.5204582690150288}
# {'attributes': ('concave points_mean', 'symmetry_mean'), 'value': 0.56181947909986}
# {'attributes': ('concave points_mean', 'fractal_dimension_mean'), 'value': 0.559655596416064}
# {'attributes': ('concave points_mean', 'radius_se'), 'value': 0.48504829132605376}
# {'attributes': ('concave points_mean', 'texture_se'), 'value': 0.5393255798418793}
# {'attributes': ('concave points_mean', 'perimeter_se'), 'value': 0.4843594263583359}
# {'attributes': ('concave points_mean', 'area_se'), 'value': 0.4655275035005039}
# {'attributes': ('concave points_mean', 'smoothness_se'), 'value': 0.542514523115611}
# {'attributes': ('concave points_mean', 'compactness_se'), 'value': 0.5166069320814997}
# {'attributes': ('concave points_mean', 'concavity_se'), 'value': 0.49070964425693653}
# {'attributes': ('concave points_mean', 'concave points_se'), 'value': 0.5292002549309511}
# {'attributes': ('concave points_mean', 'symmetry_se'), 'value': 0.5388797598733668}
# {'attributes': ('concave points_mean', 'fractal_dimension_se'), 'value': 0.5069889164878327}
# {'attributes': ('concave points_mean', 'radius_worst'), 'value': 0.5121178388740439}
# {'attributes': ('concave points_mean', 'texture_worst'), 'value': 0.5464336788218874}
# {'attributes': ('concave points_mean', 'perimeter_worst'), 'value': 0.5102475515578548}
# {'attributes': ('concave points_mean', 'area_worst'), 'value': 0.48956068373515893}
# {'attributes': ('concave points_mean', 'smoothness_worst'), 'value': 0.5580202824032235}
# {'attributes': ('concave points_mean', 'compactness_worst'), 'value': 0.5092692193361286}
# {'attributes': ('concave points_mean', 'concavity_worst'), 'value': 0.49512935160785454}
# {'attributes': ('concave points_mean', 'concave points_worst'), 'value': 0.5051923307870135}
# {'attributes': ('concave points_mean', 'symmetry_worst'), 'value': 0.5398701527637093}
# {'attributes': ('concave points_mean', 'fractal_dimension_worst'), 'value': 0.5251400580912549}
# {'attributes': ('symmetry_mean', 'fractal_dimension_mean'), 'value': 0.6355671008952923}
# {'attributes': ('symmetry_mean', 'radius_se'), 'value': 0.5609597958052821}
# {'attributes': ('symmetry_mean', 'texture_se'), 'value': 0.6152370843211077}
# {'attributes': ('symmetry_mean', 'perimeter_se'), 'value': 0.5602709308375642}
# {'attributes': ('symmetry_mean', 'area_se'), 'value': 0.5414390079797322}
# {'attributes': ('symmetry_mean', 'smoothness_se'), 'value': 0.6184260275948392}
# {'attributes': ('symmetry_mean', 'compactness_se'), 'value': 0.592518436560728}
# {'attributes': ('symmetry_mean', 'concavity_se'), 'value': 0.5666211487361649}
# {'attributes': ('symmetry_mean', 'concave points_se'), 'value': 0.6051117594101795}
# {'attributes': ('symmetry_mean', 'symmetry_se'), 'value': 0.6147912643525951}
# {'attributes': ('symmetry_mean', 'fractal_dimension_se'), 'value': 0.582900420967061}
# {'attributes': ('symmetry_mean', 'radius_worst'), 'value': 0.5880293433532722}
# {'attributes': ('symmetry_mean', 'texture_worst'), 'value': 0.6223451833011158}
# {'attributes': ('symmetry_mean', 'perimeter_worst'), 'value': 0.5861590560370832}
# {'attributes': ('symmetry_mean', 'area_worst'), 'value': 0.5654721882143872}
# {'attributes': ('symmetry_mean', 'smoothness_worst'), 'value': 0.6339317868824519}
# {'attributes': ('symmetry_mean', 'compactness_worst'), 'value': 0.5851807238153569}
# {'attributes': ('symmetry_mean', 'concavity_worst'), 'value': 0.5710408560870829}
# {'attributes': ('symmetry_mean', 'concave points_worst'), 'value': 0.5811038352662419}
# {'attributes': ('symmetry_mean', 'symmetry_worst'), 'value': 0.6157816572429377}
# {'attributes': ('symmetry_mean', 'fractal_dimension_worst'), 'value': 0.6010515625704832}
# {'attributes': ('fractal_dimension_mean', 'radius_se'), 'value': 0.558795913121486}
# {'attributes': ('fractal_dimension_mean', 'texture_se'), 'value': 0.6130732016373116}
# {'attributes': ('fractal_dimension_mean', 'perimeter_se'), 'value': 0.5581070481537682}
# {'attributes': ('fractal_dimension_mean', 'area_se'), 'value': 0.5392751252959362}
# {'attributes': ('fractal_dimension_mean', 'smoothness_se'), 'value': 0.6162621449110433}
# {'attributes': ('fractal_dimension_mean', 'compactness_se'), 'value': 0.5903545538769319}
# {'attributes': ('fractal_dimension_mean', 'concavity_se'), 'value': 0.5644572660523688}
# {'attributes': ('fractal_dimension_mean', 'concave points_se'), 'value': 0.6029478767263834}
# {'attributes': ('fractal_dimension_mean', 'symmetry_se'), 'value': 0.612627381668799}
# {'attributes': ('fractal_dimension_mean', 'fractal_dimension_se'), 'value': 0.580736538283265}
# {'attributes': ('fractal_dimension_mean', 'radius_worst'), 'value': 0.5858654606694762}
# {'attributes': ('fractal_dimension_mean', 'texture_worst'), 'value': 0.6201813006173197}
# {'attributes': ('fractal_dimension_mean', 'perimeter_worst'), 'value': 0.5839951733532871}
# {'attributes': ('fractal_dimension_mean', 'area_worst'), 'value': 0.5633083055305912}
# {'attributes': ('fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6317679041986558}
# {'attributes': ('fractal_dimension_mean', 'compactness_worst'), 'value': 0.5830168411315608}
# {'attributes': ('fractal_dimension_mean', 'concavity_worst'), 'value': 0.5688769734032868}
# {'attributes': ('fractal_dimension_mean', 'concave points_worst'), 'value': 0.5789399525824458}
# {'attributes': ('fractal_dimension_mean', 'symmetry_worst'), 'value': 0.6136177745591416}
# {'attributes': ('fractal_dimension_mean', 'fractal_dimension_worst'), 'value': 0.5988876798866871}
# {'attributes': ('radius_se', 'texture_se'), 'value': 0.5384658965473014}
# {'attributes': ('radius_se', 'perimeter_se'), 'value': 0.483499743063758}
# {'attributes': ('radius_se', 'area_se'), 'value': 0.464667820205926}
# {'attributes': ('radius_se', 'smoothness_se'), 'value': 0.541654839821033}
# {'attributes': ('radius_se', 'compactness_se'), 'value': 0.5157472487869218}
# {'attributes': ('radius_se', 'concavity_se'), 'value': 0.4898499609623586}
# {'attributes': ('radius_se', 'concave points_se'), 'value': 0.5283405716363733}
# {'attributes': ('radius_se', 'symmetry_se'), 'value': 0.5380200765787889}
# {'attributes': ('radius_se', 'fractal_dimension_se'), 'value': 0.5061292331932548}
# {'attributes': ('radius_se', 'radius_worst'), 'value': 0.511258155579466}
# {'attributes': ('radius_se', 'texture_worst'), 'value': 0.5455739955273095}
# {'attributes': ('radius_se', 'perimeter_worst'), 'value': 0.509387868263277}
# {'attributes': ('radius_se', 'area_worst'), 'value': 0.48870100044058096}
# {'attributes': ('radius_se', 'smoothness_worst'), 'value': 0.5571605991086456}
# {'attributes': ('radius_se', 'compactness_worst'), 'value': 0.5084095360415507}
# {'attributes': ('radius_se', 'concavity_worst'), 'value': 0.4942696683132767}
# {'attributes': ('radius_se', 'concave points_worst'), 'value': 0.5043326474924356}
# {'attributes': ('radius_se', 'symmetry_worst'), 'value': 0.5390104694691314}
# {'attributes': ('radius_se', 'fractal_dimension_worst'), 'value': 0.524280374796677}
# {'attributes': ('texture_se', 'perimeter_se'), 'value': 0.5377770315795836}
# {'attributes': ('texture_se', 'area_se'), 'value': 0.5189451087217516}
# {'attributes': ('texture_se', 'smoothness_se'), 'value': 0.5959321283368586}
# {'attributes': ('texture_se', 'compactness_se'), 'value': 0.5700245373027473}
# {'attributes': ('texture_se', 'concavity_se'), 'value': 0.5441272494781841}
# {'attributes': ('texture_se', 'concave points_se'), 'value': 0.5826178601521987}
# {'attributes': ('texture_se', 'symmetry_se'), 'value': 0.5922973650946144}
# {'attributes': ('texture_se', 'fractal_dimension_se'), 'value': 0.5604065217090803}
# {'attributes': ('texture_se', 'radius_worst'), 'value': 0.5655354440952916}
# {'attributes': ('texture_se', 'texture_worst'), 'value': 0.599851284043135}
# {'attributes': ('texture_se', 'perimeter_worst'), 'value': 0.5636651567791024}
# {'attributes': ('texture_se', 'area_worst'), 'value': 0.5429782889564065}
# {'attributes': ('texture_se', 'smoothness_worst'), 'value': 0.6114378876244712}
# {'attributes': ('texture_se', 'compactness_worst'), 'value': 0.5626868245573762}
# {'attributes': ('texture_se', 'concavity_worst'), 'value': 0.5485469568291022}
# {'attributes': ('texture_se', 'concave points_worst'), 'value': 0.5586099360082611}
# {'attributes': ('texture_se', 'symmetry_worst'), 'value': 0.5932877579849569}
# {'attributes': ('texture_se', 'fractal_dimension_worst'), 'value': 0.5785576633125025}
# {'attributes': ('perimeter_se', 'area_se'), 'value': 0.46397895523820815}
# {'attributes': ('perimeter_se', 'smoothness_se'), 'value': 0.5409659748533152}
# {'attributes': ('perimeter_se', 'compactness_se'), 'value': 0.5150583838192039}
# {'attributes': ('perimeter_se', 'concavity_se'), 'value': 0.48916109599464075}
# {'attributes': ('perimeter_se', 'concave points_se'), 'value': 0.5276517066686554}
# {'attributes': ('perimeter_se', 'symmetry_se'), 'value': 0.537331211611071}
# {'attributes': ('perimeter_se', 'fractal_dimension_se'), 'value': 0.505440368225537}
# {'attributes': ('perimeter_se', 'radius_worst'), 'value': 0.5105692906117482}
# {'attributes': ('perimeter_se', 'texture_worst'), 'value': 0.5448851305595916}
# {'attributes': ('perimeter_se', 'perimeter_worst'), 'value': 0.5086990032955591}
# {'attributes': ('perimeter_se', 'area_worst'), 'value': 0.48801213547286315}
# {'attributes': ('perimeter_se', 'smoothness_worst'), 'value': 0.5564717341409278}
# {'attributes': ('perimeter_se', 'compactness_worst'), 'value': 0.5077206710738328}
# {'attributes': ('perimeter_se', 'concavity_worst'), 'value': 0.49358080334555876}
# {'attributes': ('perimeter_se', 'concave points_worst'), 'value': 0.5036437825247178}
# {'attributes': ('perimeter_se', 'symmetry_worst'), 'value': 0.5383216045014135}
# {'attributes': ('perimeter_se', 'fractal_dimension_worst'), 'value': 0.5235915098289591}
# {'attributes': ('area_se', 'smoothness_se'), 'value': 0.5221340519954832}
# {'attributes': ('area_se', 'compactness_se'), 'value': 0.4962264609613719}
# {'attributes': ('area_se', 'concavity_se'), 'value': 0.4703291731368088}
# {'attributes': ('area_se', 'concave points_se'), 'value': 0.5088197838108234}
# {'attributes': ('area_se', 'symmetry_se'), 'value': 0.518499288753239}
# {'attributes': ('area_se', 'fractal_dimension_se'), 'value': 0.486608445367705}
# {'attributes': ('area_se', 'radius_worst'), 'value': 0.4917373677539162}
# {'attributes': ('area_se', 'texture_worst'), 'value': 0.5260532077017597}
# {'attributes': ('area_se', 'perimeter_worst'), 'value': 0.4898670804377271}
# {'attributes': ('area_se', 'area_worst'), 'value': 0.4691802126150312}
# {'attributes': ('area_se', 'smoothness_worst'), 'value': 0.5376398112830958}
# {'attributes': ('area_se', 'compactness_worst'), 'value': 0.4888887482160008}
# {'attributes': ('area_se', 'concavity_worst'), 'value': 0.4747488804877268}
# {'attributes': ('area_se', 'concave points_worst'), 'value': 0.4848118596668858}
# {'attributes': ('area_se', 'symmetry_worst'), 'value': 0.5194896816435816}
# {'attributes': ('area_se', 'fractal_dimension_worst'), 'value': 0.5047595869711271}
# {'attributes': ('smoothness_se', 'compactness_se'), 'value': 0.573213480576479}
# {'attributes': ('smoothness_se', 'concavity_se'), 'value': 0.5473161927519158}
# {'attributes': ('smoothness_se', 'concave points_se'), 'value': 0.5858068034259305}
# {'attributes': ('smoothness_se', 'symmetry_se'), 'value': 0.5954863083683462}
# {'attributes': ('smoothness_se', 'fractal_dimension_se'), 'value': 0.563595464982812}
# {'attributes': ('smoothness_se', 'radius_worst'), 'value': 0.5687243873690232}
# {'attributes': ('smoothness_se', 'texture_worst'), 'value': 0.6030402273168667}
# {'attributes': ('smoothness_se', 'perimeter_worst'), 'value': 0.5668541000528342}
# {'attributes': ('smoothness_se', 'area_worst'), 'value': 0.5461672322301382}
# {'attributes': ('smoothness_se', 'smoothness_worst'), 'value': 0.6146268308982028}
# {'attributes': ('smoothness_se', 'compactness_worst'), 'value': 0.5658757678311079}
# {'attributes': ('smoothness_se', 'concavity_worst'), 'value': 0.5517359001028339}
# {'attributes': ('smoothness_se', 'concave points_worst'), 'value': 0.5617988792819928}
# {'attributes': ('smoothness_se', 'symmetry_worst'), 'value': 0.5964767012586887}
# {'attributes': ('smoothness_se', 'fractal_dimension_worst'), 'value': 0.5817466065862342}
# {'attributes': ('compactness_se', 'concavity_se'), 'value': 0.5214086017178046}
# {'attributes': ('compactness_se', 'concave points_se'), 'value': 0.5598992123918192}
# {'attributes': ('compactness_se', 'symmetry_se'), 'value': 0.5695787173342348}
# {'attributes': ('compactness_se', 'fractal_dimension_se'), 'value': 0.5376878739487008}
# {'attributes': ('compactness_se', 'radius_worst'), 'value': 0.542816796334912}
# {'attributes': ('compactness_se', 'texture_worst'), 'value': 0.5771326362827554}
# {'attributes': ('compactness_se', 'perimeter_worst'), 'value': 0.5409465090187229}
# {'attributes': ('compactness_se', 'area_worst'), 'value': 0.520259641196027}
# {'attributes': ('compactness_se', 'smoothness_worst'), 'value': 0.5887192398640915}
# {'attributes': ('compactness_se', 'compactness_worst'), 'value': 0.5399681767969966}
# {'attributes': ('compactness_se', 'concavity_worst'), 'value': 0.5258283090687226}
# {'attributes': ('compactness_se', 'concave points_worst'), 'value': 0.5358912882478815}
# {'attributes': ('compactness_se', 'symmetry_worst'), 'value': 0.5705691102245773}
# {'attributes': ('compactness_se', 'fractal_dimension_worst'), 'value': 0.5558390155521229}
# {'attributes': ('concavity_se', 'concave points_se'), 'value': 0.534001924567256}
# {'attributes': ('concavity_se', 'symmetry_se'), 'value': 0.5436814295096717}
# {'attributes': ('concavity_se', 'fractal_dimension_se'), 'value': 0.5117905861241375}
# {'attributes': ('concavity_se', 'radius_worst'), 'value': 0.5169195085103487}
# {'attributes': ('concavity_se', 'texture_worst'), 'value': 0.5512353484581922}
# {'attributes': ('concavity_se', 'perimeter_worst'), 'value': 0.5150492211941597}
# {'attributes': ('concavity_se', 'area_worst'), 'value': 0.4943623533714637}
# {'attributes': ('concavity_se', 'smoothness_worst'), 'value': 0.5628219520395283}
# {'attributes': ('concavity_se', 'compactness_worst'), 'value': 0.5140708889724335}
# {'attributes': ('concavity_se', 'concavity_worst'), 'value': 0.49993102124415945}
# {'attributes': ('concavity_se', 'concave points_worst'), 'value': 0.5099940004233183}
# {'attributes': ('concavity_se', 'symmetry_worst'), 'value': 0.5446718224000142}
# {'attributes': ('concavity_se', 'fractal_dimension_worst'), 'value': 0.5299417277275598}
# {'attributes': ('concave points_se', 'symmetry_se'), 'value': 0.5821720401836863}
# {'attributes': ('concave points_se', 'fractal_dimension_se'), 'value': 0.5502811967981522}
# {'attributes': ('concave points_se', 'radius_worst'), 'value': 0.5554101191843634}
# {'attributes': ('concave points_se', 'texture_worst'), 'value': 0.5897259591322068}
# {'attributes': ('concave points_se', 'perimeter_worst'), 'value': 0.5535398318681743}
# {'attributes': ('concave points_se', 'area_worst'), 'value': 0.5328529640454784}
# {'attributes': ('concave points_se', 'smoothness_worst'), 'value': 0.6013125627135429}
# {'attributes': ('concave points_se', 'compactness_worst'), 'value': 0.5525614996464481}
# {'attributes': ('concave points_se', 'concavity_worst'), 'value': 0.538421631918174}
# {'attributes': ('concave points_se', 'concave points_worst'), 'value': 0.5484846110973329}
# {'attributes': ('concave points_se', 'symmetry_worst'), 'value': 0.5831624330740288}
# {'attributes': ('concave points_se', 'fractal_dimension_worst'), 'value': 0.5684323384015744}
# {'attributes': ('symmetry_se', 'fractal_dimension_se'), 'value': 0.5599607017405679}
# {'attributes': ('symmetry_se', 'radius_worst'), 'value': 0.5650896241267791}
# {'attributes': ('symmetry_se', 'texture_worst'), 'value': 0.5994054640746225}
# {'attributes': ('symmetry_se', 'perimeter_worst'), 'value': 0.56321933681059}
# {'attributes': ('symmetry_se', 'area_worst'), 'value': 0.5425324689878941}
# {'attributes': ('symmetry_se', 'smoothness_worst'), 'value': 0.6109920676559586}
# {'attributes': ('symmetry_se', 'compactness_worst'), 'value': 0.5622410045888637}
# {'attributes': ('symmetry_se', 'concavity_worst'), 'value': 0.5481011368605897}
# {'attributes': ('symmetry_se', 'concave points_worst'), 'value': 0.5581641160397486}
# {'attributes': ('symmetry_se', 'symmetry_worst'), 'value': 0.5928419380164445}
# {'attributes': ('symmetry_se', 'fractal_dimension_worst'), 'value': 0.57811184334399}
# {'attributes': ('fractal_dimension_se', 'radius_worst'), 'value': 0.5331987807412449}
# {'attributes': ('fractal_dimension_se', 'texture_worst'), 'value': 0.5675146206890884}
# {'attributes': ('fractal_dimension_se', 'perimeter_worst'), 'value': 0.531328493425056}
# {'attributes': ('fractal_dimension_se', 'area_worst'), 'value': 0.5106416256023599}
# {'attributes': ('fractal_dimension_se', 'smoothness_worst'), 'value': 0.5791012242704245}
# {'attributes': ('fractal_dimension_se', 'compactness_worst'), 'value': 0.5303501612033297}
# {'attributes': ('fractal_dimension_se', 'concavity_worst'), 'value': 0.5162102934750556}
# {'attributes': ('fractal_dimension_se', 'concave points_worst'), 'value': 0.5262732726542145}
# {'attributes': ('fractal_dimension_se', 'symmetry_worst'), 'value': 0.5609510946309104}
# {'attributes': ('fractal_dimension_se', 'fractal_dimension_worst'), 'value': 0.546220999958456}
# {'attributes': ('radius_worst', 'texture_worst'), 'value': 0.5726435430752996}
# {'attributes': ('radius_worst', 'perimeter_worst'), 'value': 0.5364574158112672}
# {'attributes': ('radius_worst', 'area_worst'), 'value': 0.5157705479885711}
# {'attributes': ('radius_worst', 'smoothness_worst'), 'value': 0.5842301466566358}
# {'attributes': ('radius_worst', 'compactness_worst'), 'value': 0.5354790835895409}
# {'attributes': ('radius_worst', 'concavity_worst'), 'value': 0.5213392158612669}
# {'attributes': ('radius_worst', 'concave points_worst'), 'value': 0.5314021950404257}
# {'attributes': ('radius_worst', 'symmetry_worst'), 'value': 0.5660800170171216}
# {'attributes': ('radius_worst', 'fractal_dimension_worst'), 'value': 0.5513499223446672}
# {'attributes': ('texture_worst', 'perimeter_worst'), 'value': 0.5707732557591105}
# {'attributes': ('texture_worst', 'area_worst'), 'value': 0.5500863879364146}
# {'attributes': ('texture_worst', 'smoothness_worst'), 'value': 0.6185459866044792}
# {'attributes': ('texture_worst', 'compactness_worst'), 'value': 0.5697949235373843}
# {'attributes': ('texture_worst', 'concavity_worst'), 'value': 0.5556550558091102}
# {'attributes': ('texture_worst', 'concave points_worst'), 'value': 0.5657180349882692}
# {'attributes': ('texture_worst', 'symmetry_worst'), 'value': 0.600395856964965}
# {'attributes': ('texture_worst', 'fractal_dimension_worst'), 'value': 0.5856657622925105}
# {'attributes': ('perimeter_worst', 'area_worst'), 'value': 0.5139002606723821}
# {'attributes': ('perimeter_worst', 'smoothness_worst'), 'value': 0.5823598593404467}
# {'attributes': ('perimeter_worst', 'compactness_worst'), 'value': 0.5336087962733518}
# {'attributes': ('perimeter_worst', 'concavity_worst'), 'value': 0.5194689285450778}
# {'attributes': ('perimeter_worst', 'concave points_worst'), 'value': 0.5295319077242366}
# {'attributes': ('perimeter_worst', 'symmetry_worst'), 'value': 0.5642097297009325}
# {'attributes': ('perimeter_worst', 'fractal_dimension_worst'), 'value': 0.5494796350284781}
# {'attributes': ('area_worst', 'smoothness_worst'), 'value': 0.5616729915177507}
# {'attributes': ('area_worst', 'compactness_worst'), 'value': 0.5129219284506559}
# {'attributes': ('area_worst', 'concavity_worst'), 'value': 0.4987820607223818}
# {'attributes': ('area_worst', 'concave points_worst'), 'value': 0.5088450399015407}
# {'attributes': ('area_worst', 'symmetry_worst'), 'value': 0.5435228618782366}
# {'attributes': ('area_worst', 'fractal_dimension_worst'), 'value': 0.5287927672057822}
# {'attributes': ('smoothness_worst', 'compactness_worst'), 'value': 0.5813815271187204}
# {'attributes': ('smoothness_worst', 'concavity_worst'), 'value': 0.5672416593904464}
# {'attributes': ('smoothness_worst', 'concave points_worst'), 'value': 0.5773046385696053}
# {'attributes': ('smoothness_worst', 'symmetry_worst'), 'value': 0.6119824605463011}
# {'attributes': ('smoothness_worst', 'fractal_dimension_worst'), 'value': 0.5972523658738467}
# {'attributes': ('compactness_worst', 'concavity_worst'), 'value': 0.5184905963233515}
# {'attributes': ('compactness_worst', 'concave points_worst'), 'value': 0.5285535755025104}
# {'attributes': ('compactness_worst', 'symmetry_worst'), 'value': 0.5632313974792063}
# {'attributes': ('compactness_worst', 'fractal_dimension_worst'), 'value': 0.5485013028067518}
# {'attributes': ('concavity_worst', 'concave points_worst'), 'value': 0.5144137077742363}
# {'attributes': ('concavity_worst', 'symmetry_worst'), 'value': 0.5490915297509322}
# {'attributes': ('concavity_worst', 'fractal_dimension_worst'), 'value': 0.5343614350784778}
# {'attributes': ('concave points_worst', 'symmetry_worst'), 'value': 0.5591545089300911}
# {'attributes': ('concave points_worst', 'fractal_dimension_worst'), 'value': 0.5444244142576367}
# {'attributes': ('symmetry_worst', 'fractal_dimension_worst'), 'value': 0.5791022362343325}
# ========================================== find best value ===================================
# [{'attributes': ('smoothness_mean', 'symmetry_mean'), 'value': 0.6410110231715836}]
# =============================================================================================
#
# ========================================== Subset_Score Round 2 =============================
#
# {'attributes': ('radius_mean', 'smoothness_mean', 'symmetry_mean'), 'value': 0.6156893370947167}
# {'attributes': ('texture_mean', 'smoothness_mean', 'symmetry_mean'), 'value': 0.6294641116197551}
# {'attributes': ('perimeter_mean', 'smoothness_mean', 'symmetry_mean'), 'value': 0.6142054662994582}
# {'attributes': ('area_mean', 'smoothness_mean', 'symmetry_mean'), 'value': 0.6009991127170774}
# {'attributes': ('smoothness_mean', 'compactness_mean', 'symmetry_mean'), 'value': 0.6102810061184175}
# {'attributes': ('smoothness_mean', 'concavity_mean', 'symmetry_mean'), 'value': 0.5861888142704489}
# {'attributes': ('smoothness_mean', 'concave points_mean', 'symmetry_mean'), 'value': 0.589310006987933}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.6384750881848879}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'radius_se'), 'value': 0.5887368847915477}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'texture_se'), 'value': 0.6249217438020981}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'perimeter_se'), 'value': 0.5882776414797358}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'area_se'), 'value': 0.5757230262411811}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_se'), 'value': 0.6270477059845859}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'compactness_se'), 'value': 0.6097759786285116}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'concavity_se'), 'value': 0.5925111200788029}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'concave points_se'), 'value': 0.6181715271948126}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'symmetry_se'), 'value': 0.6246245304897564}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_se'), 'value': 0.6033639682327337}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'radius_worst'), 'value': 0.6067832498235411}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'texture_worst'), 'value': 0.6296604764554368}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'perimeter_worst'), 'value': 0.6055363916127484}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'area_worst'), 'value': 0.5917451463976179}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'smoothness_worst'), 'value': 0.6373848788429942}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'compactness_worst'), 'value': 0.6048841701315976}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'concavity_worst'), 'value': 0.5954575916460816}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'concave points_worst'), 'value': 0.6021662444321875}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'symmetry_worst'), 'value': 0.6252847924166515}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_worst'), 'value': 0.6154647293016818}
# ========================================== find best value ===================================
# [{'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.6384750881848879}]
# =============================================================================================
#
# ========================================== Subset_Score Round 3 =============================
#
# {'attributes': ('radius_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.6201178073739116}
# {'attributes': ('texture_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.6304488882676904}
# {'attributes': ('perimeter_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.6190049042774677}
# {'attributes': ('area_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.6091001390906821}
# {'attributes': ('smoothness_mean', 'compactness_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.6160615591416873}
# {'attributes': ('smoothness_mean', 'concavity_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.5979924152557108}
# {'attributes': ('smoothness_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean'), 'value': 0.6003333097938238}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se'), 'value': 0.5999034681465348}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se'), 'value': 0.6270421124044476}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'perimeter_se'), 'value': 0.5995590356626759}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'area_se'), 'value': 0.5901430742337599}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se'), 'value': 0.6286365840413134}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'compactness_se'), 'value': 0.6156827885242577}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'concavity_se'), 'value': 0.6027341446119762}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'concave points_se'), 'value': 0.6219794499489835}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'symmetry_se'), 'value': 0.6268192024201913}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'fractal_dimension_se'), 'value': 0.6108737807274243}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_worst'), 'value': 0.6134382419205299}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_worst'), 'value': 0.6305961618944517}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'perimeter_worst'), 'value': 0.6125030982624353}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'area_worst'), 'value': 0.6021596643510874}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6363894636851197}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'compactness_worst'), 'value': 0.6120139321515723}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'concavity_worst'), 'value': 0.6049439982874352}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'concave points_worst'), 'value': 0.6099754878770147}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'symmetry_worst'), 'value': 0.6273143988653627}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'fractal_dimension_worst'), 'value': 0.6199493515291354}
# ========================================== find best value ===================================
# [{'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6363894636851197}]
# =============================================================================================
#
# ========================================== Subset_Score Round 4 =============================
#
# {'attributes': ('radius_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6221207639362925}
# {'attributes': ('texture_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6303856286513154}
# {'attributes': ('perimeter_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6212304414591372}
# {'attributes': ('area_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6133066293097087}
# {'attributes': ('smoothness_mean', 'compactness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6188757653505129}
# {'attributes': ('smoothness_mean', 'concavity_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6044204502417317}
# {'attributes': ('smoothness_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst'), 'value': 0.6062931658722222}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'smoothness_worst'), 'value': 0.605949292554391}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'smoothness_worst'), 'value': 0.6276602079607212}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'perimeter_se', 'smoothness_worst'), 'value': 0.6056737465673038}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'area_se', 'smoothness_worst'), 'value': 0.598140977424171}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_se', 'smoothness_worst'), 'value': 0.6289357852702138}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'compactness_se', 'smoothness_worst'), 'value': 0.6185727488565693}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'concavity_se', 'smoothness_worst'), 'value': 0.608213833726744}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'concave points_se', 'smoothness_worst'), 'value': 0.6236100779963498}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'symmetry_se', 'smoothness_worst'), 'value': 0.6274818799733162}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'fractal_dimension_se', 'smoothness_worst'), 'value': 0.6147255426191025}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_worst', 'smoothness_worst'), 'value': 0.616777111573587}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_worst', 'smoothness_worst'), 'value': 0.6305034475527245}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'perimeter_worst', 'smoothness_worst'), 'value': 0.6160289966471113}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'area_worst', 'smoothness_worst'), 'value': 0.607754249518033}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst', 'compactness_worst'), 'value': 0.6156376637584209}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst', 'concavity_worst'), 'value': 0.6099817166671112}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst', 'concave points_worst'), 'value': 0.6140069083387749}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst', 'symmetry_worst'), 'value': 0.6278780371294532}
# {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'smoothness_worst', 'fractal_dimension_worst'), 'value': 0.6219859992604715}
# ========================================== find best value ===================================
# [{'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_worst', 'smoothness_worst'), 'value': 0.6305034475527245}]
# =============================================================================================
#
# ========================================== Subset_Score Round 5 =============================
# {'attributes': ('radius_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_worst', 'smoothness_worst'), 'value': 0.6195938671174342}
# {'attributes': ('texture_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_worst', 'smoothness_worst'), 'value': 0.6264812543799534}
# {'attributes': ('perimeter_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_worst', 'smoothness_worst'), 'value': 0.6188519317198049}
# ...
# ========================================== find best value ===================================
# [{'attributes': ('radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst'), 'value': 0.557861340847033}]
# =============================================================================================
#
# ========================================== Subset_Score Round 28 =============================
#
# {'attributes': ('radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst'), 'value': 0.555057308282245}
# {'attributes': ('radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst'), 'value': 0.5539746405550793}
# ========================================== find best value ===================================
# [{'attributes': ('radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst'), 'value': 0.555057308282245}]
# =============================================================================================
#
# ========================================== Subset_Score Round 29 =============================
#
# {'attributes': ('radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst'), 'value': 0.5513936324188493}
# ========================================== find best value ===================================
# [{'attributes': ('radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst'), 'value': 0.5513936324188493}]
# =============================================================================================
#
#
# best_subset_per_round :
#  =============== SubsetRanking ===============
# [{'attributes': ('smoothness_mean', 'symmetry_mean'),
#   'value': 0.6410110231715836},
#  {'attributes': ('smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean'),
#   'value': 0.6384750881848879},
#  {'attributes': ('smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'smoothness_worst'),
#   'value': 0.6363894636851197},
#  {'attributes': ('smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_worst',
#    'smoothness_worst'),
#   'value': 0.6305034475527245},
#  {'attributes': ('texture_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_worst',
#    'smoothness_worst'),
#   'value': 0.6264812543799534},
#  {'attributes': ('texture_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'smoothness_se',
#    'texture_worst',
#    'smoothness_worst'),
#   'value': 0.6225726568414729},
#  {'attributes': ('texture_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'smoothness_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst'),
#   'value': 0.6189801160996371},
#  {'attributes': ('texture_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst'),
#   'value': 0.616064901540025},
#  {'attributes': ('texture_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'symmetry_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst'),
#   'value': 0.6136435658986327},
#  {'attributes': ('texture_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'concave points_se',
#    'symmetry_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst'),
#   'value': 0.6099025631115997},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'concave points_se',
#    'symmetry_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst'),
#   'value': 0.6061645132640483},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'concave points_se',
#    'symmetry_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.6029497154408044},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'smoothness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'concave points_se',
#    'symmetry_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5999243323775475},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'concave points_se',
#    'symmetry_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5965174416865167},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concave points_se',
#    'symmetry_se',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5934417196775074},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concave points_se',
#    'symmetry_se',
#    'radius_worst',
#    'texture_worst',
#    'smoothness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5901997187039749},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concave points_se',
#    'symmetry_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'smoothness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5871101303590363},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concave points_se',
#    'symmetry_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5842427795007514},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5814341334434654},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concave points_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5787218740867954},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concave points_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5760970294377622},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concavity_worst',
#    'concave points_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5729776250532977},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concavity_worst',
#    'concave points_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5697498620882955},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'area_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concavity_worst',
#    'concave points_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.566688403318751},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'concave points_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'area_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concavity_worst',
#    'concave points_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5635814637534388},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'concave points_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'radius_se',
#    'texture_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'area_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concavity_worst',
#    'concave points_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5606409876155882},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'concave points_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'radius_se',
#    'texture_se',
#    'perimeter_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'area_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concavity_worst',
#    'concave points_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.557861340847033},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'concavity_mean',
#    'concave points_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'radius_se',
#    'texture_se',
#    'perimeter_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'area_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concavity_worst',
#    'concave points_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.555057308282245},
#  {'attributes': ('radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'concavity_mean',
#    'concave points_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'radius_se',
#    'texture_se',
#    'perimeter_se',
#    'area_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'area_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concavity_worst',
#    'concave points_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'),
#   'value': 0.5513936324188493}]

# %% [markdown]
# <h2> The Best Candidate Subset by SFS

# %%
find_best_subset(best_subset_per_round)
# Out:
# ========================================== find best value ===================================
# [{'attributes': ('smoothness_mean', 'symmetry_mean'), 'value': 0.6410110231715836}]
# =============================================================================================
# [{'attributes': ('smoothness_mean', 'symmetry_mean'),
#   'value': 0.6410110231715836}]
